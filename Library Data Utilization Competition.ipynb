# %% [markdown]
# <a href="https://colab.research.google.com/github/jooyoung227/ESAA-14-23-/blob/main/Library%20Data%20Utilization%20Competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import os


# !apt-get install -y fonts-nanum

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

font_entry = fm.FontEntry(fname=font_path, name='NanumGothic')
fm.fontManager.ttflist.insert(0, font_entry)

plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.

# %% [markdown]
# # 서울시 자치구별 대표 도서관 선정
# - 도서수가 가장 많은 도서관으로 선정함

# %%
import pandas as pd

# %%
#1. 강남구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_강남구_도서관_20251226.csv')
df.head()
df.head()

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

import os

save_folder = "/content/drive/MyDrive/ESA4_공모전/대표도서관_총자료수"
os.makedirs(save_folder, exist_ok=True)

library.to_csv(
    os.path.join(save_folder, f"서울특별시_강남구_도서관.csv"),
    index=False,
    encoding="utf-8-sig"
)

library.head(3)
# Out:
#          도서관명    시도명 시군구명                         소재지도로명주소     데이터기준일자   총 자료수
# 10  도곡정보문화도서관  서울특별시  강남구        서울특별시 강남구 도곡로18길 57, 3~6층  2025-12-26  121790
# 22      못골도서관  서울특별시  강남구                서울특별시 강남구 자곡로 116  2025-12-26   74971
# 14      대치도서관  서울특별시  강남구  서울특별시 강남구 삼성로 212 (은마상가 C블럭 2층)  2025-12-26   59374

# %%
#2. 강동구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_강동구_도서관_20230818.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#     도서관명    시도명 시군구명                          소재지도로명주소     데이터기준일자  총 자료수
# 2  강일도서관  서울특별시  강동구  서울특별시 강동구 아리수로93길 9-14,4,5층(강일동)  2023-08-18  96625
# 3  암사도서관  서울특별시  강동구  서울특별시 강동구 고덕로20길 42 (암사동, 암사도서관)  2023-08-18  95704
# 1  해공도서관  서울특별시  강동구    서울특별시 강동구 올림픽로 702 (천호동, 해공공원)  2023-08-18  91109

# %%
#3. 강북구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_강북구_도서관_20251126.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#            도서관명    시도명 시군구명                   소재지도로명주소     데이터기준일자   총 자료수
# 0     강북문화정보도서관  서울특별시  강북구     서울특별시 강북구 오현로 145 (번동)  2025-11-26  249473
# 2     솔샘문화정보도서관  서울특별시  강북구    서울특별시 강북구 솔샘로 177 (미아동)  2025-11-26   54757
# 1  강북청소년문화정보도서관  서울특별시  강북구  서울특별시 강북구 삼양로54길 68 (미아동)  2025-11-26   47710

# %%
#4.강서구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_강서구_도서관_20260414.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#       도서관명    시도명 시군구명              소재지도로명주소     데이터기준일자  총 자료수
# 34   등빛도서관  서울특별시  강서구   서울특별시 강서구 강서로62길 48  2026-04-14  98275
# 33  곰달래도서관  서울특별시  강서구    서울특별시 강서구 강서로5길 50  2026-04-14  79885
# 35   가양도서관  서울특별시  강서구  서울특별시 강서구 양천로61길 101  2026-04-14  73473

# %%
#5.관악구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_관악구_도서관_20251203.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#       도서관명    시도명 시군구명              소재지도로명주소     데이터기준일자   총 자료수
# 0  관악중앙도서관  서울특별시  관악구    서울특별시 관악구 신림로3길 35  2025-12-03  205162
# 1  글빛정보도서관  서울특별시  관악구  서울특별시 관악구 관악로 30길 23  2025-12-03   71784
# 4  조원작은도서관  서울특별시  관악구  서울특별시 관악구 조원로 12길 25  2025-12-03   65557

# %%
#6. 광진구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_광진구_도서관_20251105.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#           도서관명    시도명 시군구명                   소재지도로명주소     데이터기준일자   총 자료수
# 0      광진정보도서관  서울특별시  광진구  서울특별시 광진구 아차산로78길 90(광장동)  2025-11-05  321873
# 2  중곡문화체육센터도서관  서울특별시  광진구     서울특별시 광진구 능동로 433(중곡동)  2025-11-05   80487
# 1      자양한강도서관  서울특별시  광진구   서울특별시 광진구 뚝섬로52길 66(자양동)  2025-11-05   43651

# %%
#7. 구로구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_구로구_도서관_20241101.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#        도서관명    시도명 시군구명                              소재지도로명주소     데이터기준일자  \
# 0    꿈나무도서관  서울특별시  구로구  서울특별시 구로구 구로동로26길 54, 2층 (구로구시설관리공단)  2024-11-01
# 3  개봉어린이도서관  서울특별시  구로구                  서울특별시 구로구 경인로 318-15  2024-11-01
# 1    꿈마을도서관  서울특별시  구로구            서울특별시 구로구 디지털로27다길 65 (2층)  2024-11-01
#
#    총 자료수
# 0  71647
# 3  43891
# 1  43178

# %%
#8. 금천구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_금천구_도서관_20260408.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#         도서관명    시도명 시군구명                         소재지도로명주소     데이터기준일자   총 자료수
# 0  금천구립독산도서관  서울특별시  금천구            서울특별시 금천구 독산로 54길 114  2026-04-08  124102
# 3  금천구립시흥도서관  서울특별시  금천구                서울특별시 금천구 금하로 764  2026-04-08   95178
# 1  금천구립가산도서관  서울특별시  금천구  서울특별시 금천구 가산로5길 43, 금천구립가산정보도서관  2026-04-08   83197

# %%
#9.노원구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_노원구_도서관_20260408.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#       도서관명    시도명  시군구명              소재지도로명주소     데이터기준일자   총 자료수
# 0  노원중앙도서관  서울특별시  노원구　   서울특별시 노원구 노원로34길 43  2026-04-08  172591
# 3    상계도서관  서울특별시  노원구　  서울특별시 노원구 동일로243길 57  2026-04-08   76751
# 4    불암도서관  서울특별시  노원구　     서울특별시 노원구 중계로 106  2026-04-08   69167

# %%
#10. 도봉구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_도봉구_도서관_20180515.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#                      도서관명    시도명       시군구명                    소재지도로명주소  \
# 24   서울특별시교육청도봉도서관(종합자료실)  서울특별시  서울특별시 도봉구  서울특별시 도봉구 도봉구 삼양로 556(쌍문동)
# 25  서울특별시교육청도봉도서관(어린이자료실)  서울특별시  서울특별시 도봉구  서울특별시 도봉구 도봉구 삼양로 556(쌍문동)
# 27       도봉문화정보도서관(종합자료실)  서울특별시  서울특별시 도봉구  서울특별시 도봉구 도봉구 덕릉로 315 (창동)
#
#        데이터기준일자   총 자료수
# 24  2018-05-01  161366
# 25  2018-05-01   56850
# 27  2018-05-01   45083

# %%
#11. 동대문구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_동대문구_도서관.csv', encoding='cp949')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#               도서관명    시도명  시군구명                     소재지도로명주소     데이터기준일자  \
# 8   서울특별시교육청동대문도서관  서울특별시  동대문구   서울특별시 동대문구 천호대로4길 22 (신설동)  2025-12-31
# 1       동대문구정보화도서관  서울특별시  동대문구  서울특별시 동대문구 회기로10길 60 (청량리동)  2025-12-31
# 11   한국국방연구원 자료정보팀  서울특별시  동대문구     서울특별시 동대문구 회기로 37 (청량리동)  2025-12-31
#
#        총 자료수
# 8   208830.0
# 1   172848.0
# 11  144609.0

# %%
#12. 동작구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_동작구_도서관_20251202.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#         도서관명    시도명 시군구명               소재지도로명주소     데이터기준일자  총 자료수
# 1    사당솔밭도서관  서울특별시  동작구       서울특별시 동작구 솔밭로 86  2025-12-02  71971
# 0     김영삼도서관  서울특별시  동작구         서울특별시 동작구 매봉로1  2025-12-02  61402
# 2  동작영어마루도서관  서울특별시  동작구  서울특별시 동작구 장승배기로16길 98  2025-12-02  41788

# %%
#13. 마포구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_마포구_도서관_20251128.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#       도서관명    시도명 시군구명                 소재지도로명주소     데이터기준일자   총 자료수
# 0  마포중앙도서관  서울특별시  마포구        서울특별시 마포구 성산로 128  2025-11-28  253066
# 2    서강도서관  서울특별시  마포구  서울특별시 마포구 독막로 165, 3~5층  2025-11-28   78912
# 1  소금나루도서관  서울특별시  마포구         서울특별시 마포구 숭문길 72  2025-11-28   45865

# %%
#14. 서대문구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_서대문구_도서관_20250809.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#           도서관명    시도명  시군구명                 소재지도로명주소     데이터기준일자   총 자료수
# 0     이진아기념도서관  서울특별시  서대문구     서울특별시 서대문구 독립문공원길 80  2025-08-09  182865
# 1  남가좌새롬어린이도서관  서울특별시  서대문구  서울특별시 서대문구 증가로10길 16-15  2025-08-09   69481
# 2      홍은도담도서관  서울특별시  서대문구     서울특별시 서대문구 홍은중앙로 129  2025-08-09   43104

# %%
#15. 서초구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_서초구_도서관_20251222.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#     도서관명    시도명 시군구명               소재지도로명주소     데이터기준일자   총 자료수
# 0  반포도서관  서울특별시  서초구      서울특별시 서초구 고무래로 34  2025-12-22  163574
# 2  양재도서관  서울특별시  서초구      서울특별시 서초구 양재천로 33  2025-12-22   90585
# 1  내곡도서관  서울특별시  서초구  서울특별시 서초구 청계산로7길 9-20  2025-12-22   87225

# %%
#16.성동구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_성동구_도서관_20250618.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)

library.head(3)
# Out:
#         도서관명    시도명 시군구명                           소재지도로명주소     데이터기준일자  \
# 6    성동구립도서관  서울특별시  성동구   서울특별시 성동구 행당동 고산자로10길 9 성동문화정보센터  2025-06-18
# 9  성동구립용답도서관  서울특별시  성동구  서울특별시 성동구 용답동 용답중앙3길 10 성동구립용답도서관  2025-06-18
# 5  성동구립금호도서관  서울특별시  성동구     서울특별시 성동구 금호동1가 난계로 20 금호작은도서관  2025-06-18
#
#     총 자료수
# 6  218728
# 9  100617
# 5   97003

# %%
#17. 성북구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_성북구_도서관_20250801.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#       도서관명    시도명 시군구명              소재지도로명주소     데이터기준일자   총 자료수
# 0  성북정보도서관  서울특별시  성북구  서울특별시 성북구 화랑로18자길 13  2025-08-01  200008
# 1   아리랑도서관  서울특별시  성북구     서울특별시 성북구 아리랑로 82  2025-08-01   94658
# 6  달빛마루도서관  서울특별시  성북구     서울특별시 성북구 종암로 167  2025-08-01   60081

# %%
#18. 송파구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_송파구_도서관_20231205.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#         도서관명    시도명 시군구명                   소재지도로명주소     데이터기준일자   총 자료수
# 0   송파글마루도서관  서울특별시  송파구    서울특별시 송파구 충민로 120 (장지동)  2023-12-05  110754
# 1   송파어린이도서관  서울특별시  송파구   서울특별시 송파구 올림픽로 105 (잠실동)  2023-12-05   90445
# 10   송파위례도서관  서울특별시  송파구  서울특별시 송파구 위례광장로 210 (장지동)  2023-12-05   53956

# %%
#19. 양천구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_양천구_도서관_20241001.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#         도서관명    시도명 시군구명                 소재지도로명주소     데이터기준일자  총 자료수
# 8    양천중앙도서관  서울특별시  양천구  서울특별시 양천구 신정로7길 81(신정동)  2024-10-01  82853
# 16  영어특성화도서관  서울특별시  양천구        서울특별시 양천구 목동동로 81  2024-10-01  69416
# 10   신월음악도서관  서울특별시  양천구       서울특별시 양천구 오목로5길 34  2024-10-01  62980

# %%
#20. 영등포구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_영등포구_도서관_20250904.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#     도서관명    시도명  시군구명                  소재지도로명주소     데이터기준일자  총 자료수
# 8  문래도서관  서울특별시  영등포구      서울특별시 영등포구 문래로20길 49  2025-09-04  75999
# 9  대림도서관  서울특별시  영등포구          서울특별시 영등포구 도신로27  2025-09-04  73894
# 7  선유도서관  서울특별시  영등포구  서울특별시 영등포구 선유로 43가길 10-8  2025-09-04  73808

# %%
#21. 용산구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_용산구_도서관_20250805.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#            도서관명    시도명 시군구명             소재지도로명주소     데이터기준일자  총 자료수
# 1     용산 꿈나무도서관  서울특별시  용산구    서울특별시 용산구 백범로 329  2025-08-05  59969
# 0      구립 청파도서관  서울특별시  용산구  서울특별시 용산구 청파로93길 27  2025-08-05  44078
# 3  청파 어린이 영어도서관  서울특별시  용산구  서울특별시 용산구 청파로49길 34  2025-08-05  20181

# %%
#22. 은평구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_은평구_도서관_20250627.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#         도서관명    시도명 시군구명                  소재지도로명주소     데이터기준일자   총 자료수
# 0    은평구립도서관  서울특별시  은평구  서울특별시 은평구 통일로 79가길 13-84  2025-06-27  246740
# 5  구산동 도서관마을  서울특별시  은평구   서울특별시 은평구 연서로 13길 29-23  2025-06-27   78664
# 1    증산정보도서관  서울특별시  은평구         서울특별시 은평구 증산로5길 6  2025-06-27   77377

# %%
#23. 종로구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_종로구_도서관_20251202.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#           도서관명    시도명 시군구명                         소재지도로명주소     데이터기준일자  총 자료수
# 0      청운문학도서관  서울특별시  종로구             서울특별시 종로구 자하문로36길 40  2025-12-02  44784
# 1       아름꿈도서관  서울특별시  종로구              서울특별시 종로구 종로58가길 19  2025-12-02  35426
# 2  어린이청소년국학도서관  서울특별시  종로구  서울특별시 종로구 명륜길 26(명륜동 와룡문화센터 5층)  2025-12-02  30346

# %%
#24. 중구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_중구_도서관_20251113.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#          도서관명    시도명 시군구명               소재지도로명주소     데이터기준일자  총 자료수
# 1      어울림도서관  서울특별시   중구  서울특별시 중구 다산로38길 66-35  2025-11-13  87758
# 0       가온도서관  서울특별시   중구     서울특별시 중구 동호로14길 18  2025-11-13  81874
# 2  남산타운어린이도서관  서울특별시   중구        서울특별시 중구 다산로 32  2025-11-13  39363

# %%
#25. 중랑구
df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울특별시_중랑구_도서관_20250531.csv')

library = df[[
    '도서관명',
    '시도명',
    '시군구명',
    '자료수(도서)',
    '자료수(연속간행물)',
    '자료수(비도서)',
    '소재지도로명주소',
    '데이터기준일자'
]].copy()

library['총 자료수'] = (
    library[['자료수(도서)', '자료수(연속간행물)', '자료수(비도서)']]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .sum(axis=1)
)

library = library[[
    '도서관명',
    '시도명',
    '시군구명',
    '소재지도로명주소',
    '데이터기준일자',
    '총 자료수'
]]

library = library.sort_values(by='총 자료수', ascending=False)
library.head(3)
# Out:
#           도서관명    시도명 시군구명                   소재지도로명주소     데이터기준일자   총 자료수
# 0    중랑구립정보도서관  서울특별시  중랑구   서울특별시 중랑구 신내로15길 197(묵동)  2025-05-31  210696
# 1  중랑구립면목정보도서관  서울특별시  중랑구     서울특별시 중랑구 면목로 397(면목동)  2025-05-31  104999
# 4      중랑상봉도서관  서울특별시  중랑구  서울특별시 중랑구 동일로114길 10(상봉동)  2025-05-31   68364

# %% [markdown]
# # 자치구별 대표 도서관 장서대출 데이터

# %%
import os
import pandas as pd

# %% [markdown]
# 1. 강남구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/강남구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강남구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()
# Out:
# /tmp/ipykernel_1153/2554472106.py:17: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2554472106.py:17: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2554472106.py:17: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2554472106.py:17: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2554472106.py:17: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2554472106.py:17: DtypeWarning: Columns (4,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2554472106.py:17: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2554472106.py:17: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2554472106.py:17: DtypeWarning: Columns (4,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
#                                          도서명  \
# 0  Love from the Very Hungry Caterpillar =
# 1          (The) Very hungry caterpillar =
# 2                 Narwhalicorn and jelly =
# 3                                 Ghosts =
# 4                Horrible Harry's secret =
#
#                                          저자                       출판사    권  \
# 0                             by Eric Carle          Grosset & Dunlap  NaN
# 1                             by Eric Carle              Puffin Books  NaN
# 2                            by Ben Clanton  HarperCollins Publishers  NaN
# 3  by Raina Telgemeier color by Braden Lamb                   Graphix  NaN
# 4  by Suzy Kline illus. by Frank Remkiewicz                    Puffin  NaN
#
#   주제분류번호  도서권수  대출건수
# 0  843.6     1     0
# 1  843.6     1     0
# 2    843     1     0
# 3  843.6     1     0
# 4    843     1     0

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4398384 entries, 0 to 4398383
# Data columns (total 7 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   도서명     object
#  1   저자      object
#  2   출판사     object
#  3   권       object
#  4   주제분류번호  object
#  5   도서권수    int64
#  6   대출건수    int64
# dtypes: int64(2), object(5)
# memory usage: 234.9+ MB

# %% [markdown]
# 2. 강동구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/강동구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강동구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()
# Out:
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/225775858.py:17: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
#                                                  도서명                      저자  \
# 0                                 명탐견 오드리 예감은 꼬리에서부터            정은숙 글;이주희 그림
# 1                                         질문하는 우주 사전            신광복 글;이형진 그림
# 2                                       도로를 건너는 야생동물  글·그림: 소소한소통 ;엮음: 국립생태원
# 3  새벽부터 황혼까지 :스웨덴국립미술관 컬렉션=From dawn to dusk : Na...             마이아트뮤지엄 [편]
# 4                                     (설민석의) 세계사 대모험     설민석,김정욱 [공]글;박성일 그림
#
#      출판사    권   주제분류번호  도서권수  대출건수
# 0    사계절    4    813.8     1     1
# 1     풀빛    6     82.0     1     1
# 2  국립생태원  NaN    491.0     1     0
# 3    NaN  NaN  606.923     1     0
# 4   단꿈아이   20    909.0     1     1

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3956132 entries, 0 to 3956131
# Data columns (total 7 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   도서명     object
#  1   저자      object
#  2   출판사     object
#  3   권       object
#  4   주제분류번호  object
#  5   도서권수    int64
#  6   대출건수    int64
# dtypes: int64(2), object(5)
# memory usage: 211.3+ MB

# %% [markdown]
# 3. 강북구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/강북구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강북구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()
# Out:
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2037235236.py:17: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
#                도서명   저자    출판사    권 주제분류번호  도서권수  대출건수
# 0     관점하나 바꿨을 뿐인데  이민규   유노북스  NaN    NaN     1     0
# 1      치매 한방에 치료하기  김영찬  예감출판사  NaN    NaN     1     0
# 2    할아버지 할머니의 커플티  리광푸    섬드레  NaN    NaN     1     0
# 3  엄마의 엄마의 엄마는 이상해  헤이란  사유와공감  NaN    NaN     1     0
# 4       들꽃, 치매를 앓다  박영서     찬샘  NaN    NaN     1     0

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7231097 entries, 0 to 7231096
# Data columns (total 7 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   도서명     object
#  1   저자      object
#  2   출판사     object
#  3   권       object
#  4   주제분류번호  object
#  5   도서권수    int64
#  6   대출건수    int64
# dtypes: int64(2), object(5)
# memory usage: 386.2+ MB

# %% [markdown]
# 4. 강서구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/강서구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강서구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()
# Out:
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/2780962415.py:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
#                            도서명                                저자     출판사    권  \
# 0                        동구 똥꾸                      오은영 글 윤민경 그림     효리원  NaN
# 1  돈은, 너로부터다 : 부를 묻자 돈의 신이 답했다                       김종봉 제갈현열 지음    다산북스  NaN
# 2               (유현준의)인문 건축 기행                            유현준 지음   을유문화사  NaN
# 3            챗GPT, 인생의 질문에 답하다  챗GPT 이안 토머스; 재스민 왕 [공]지음; 이경식 옮김    현대지성  NaN
# 4                  경제지표를 읽는 시간                     빈센트 김두언 [공]지음  위즈덤하우스  NaN
#
#     주제분류번호  도서권수  대출건수
# 0    813.8     1     0
# 1    327.8     1     0
# 2    610.9     1     0
# 3   004.73     1     0
# 4  327.856     1     0

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3492963 entries, 0 to 3492962
# Data columns (total 7 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   도서명     object
#  1   저자      object
#  2   출판사     object
#  3   권       object
#  4   주제분류번호  object
#  5   도서권수    int64
#  6   대출건수    int64
# dtypes: int64(2), object(5)
# memory usage: 186.5+ MB

# %% [markdown]
# 5. 관악구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/관악구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_관악구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()
# Out:
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
# /tmp/ipykernel_1153/1886427903.py:17: DtypeWarning: Columns (5,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')
#                                   도서명      저자           출판사    권 주제분류번호  도서권수  \
# 0  메이저리그, 진심의 기록:숫자 대신 마음으로 쓴 MLB 이야기  전훈칠 지음           교유당  NaN  695.7     1
# 1                                  탱크  김희재 지음         한겨레출판  NaN  813.7     1
# 2                  김 대리가 죽었대:서경희 장편소설  서경희 지음         &(앤드)  NaN  813.7     1
# 3          아주 사적인 여행:모두가 낯설고 유일한 세계에서  양주안 지음  알에이치코리아(RHK)  NaN  814.7     1
# 4  최인훈은 이렇게 말했다:최인훈과 나눈 예술철학, 40년의 배움  김기우 지음            창해  NaN  810.9     1
#
#    대출건수
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7650082 entries, 0 to 7650081
# Data columns (total 7 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   도서명     object
#  1   저자      object
#  2   출판사     object
#  3   권       object
#  4   주제분류번호  object
#  5   도서권수    int64
#  6   대출건수    int64
# dtypes: int64(2), object(5)
# memory usage: 408.6+ MB

# %% [markdown]
# 6. 광진구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/광진구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_광진구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6710/3069784798.py in <cell line: 0>()
#       4
#       5 file_list = []
# ----> 6 for root, dirs, files in os.walk(base_path):
#       7     for file in files:
#       8         if file.lower().endswith('.csv') and '월별_통합본' not in file:
#
# NameError: name 'os' is not defined

# %%
final_df.info()

# %% [markdown]
# 7. 구로구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/구로구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_구로구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 8. 금천구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/금천구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_금천구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 9. 노원구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/노원구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_노원구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 10. 도봉구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/도봉구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_도봉구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 11. 동대문구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/동대문구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_동대문구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 12. 동작구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/동작구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_동작구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 13. 마포구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/마포구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_마포구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 14. 서대문구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서대문구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_대문구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 15. 서초구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서초구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_서초구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 16. 성동구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/성동구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_성동구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 17. 성북구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/성북구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_성북구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 18. 송파구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/송파구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_송파구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 19. 양천구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/양천구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_양천구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 20. 영등포구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/영등포구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_영등포구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 21. 용산구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/용산구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_용산구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %%
final_df.info()

# %% [markdown]
# 22. 은평구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/은평구/'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_은평구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %%
final_df.info()

# %%
final_df.head()

# %% [markdown]
# 23. 종로구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/종로구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_종로구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %% [markdown]
# 24. 중구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/중구/'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_중구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %% [markdown]
# 25. 중랑구

# %%
base_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/중량구'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_중랑구.csv'
target_columns = ['도서명', '저자', '출판사', '권', '주제분류번호', '도서권수', '대출건수']

file_list = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.lower().endswith('.csv') and '월별_통합본' not in file:
            file_list.append(os.path.join(root, file))

combined_list = []

if file_list:
    for file_path in file_list:
        try:
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except:
                df = pd.read_csv(file_path, encoding='cp949')

            df.columns = df.columns.str.strip()
            available_columns = [col for col in target_columns if col in df.columns]
            combined_list.append(df[available_columns].copy())
        except:
            pass

    if combined_list:
        final_df = pd.concat(combined_list, ignore_index=True)
        existing_targets = [col for col in target_columns if col in final_df.columns]
        final_df = final_df[existing_targets]
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

final_df.head()

# %% [markdown]
# # 행정동 단위 서울 생활인구 연령대 재분류
# 5세 단위로 제공된 연령별 생활인구 데이터를 10세 단위 연령대로 재분류하였다.

# %%
from pathlib import Path
import pandas as pd
import csv
import re

INPUT_DIR = Path("/content/drive/MyDrive/ESAA YB 4조/주영/행정구역별 시간대 연령대 성별 유동인구")
OUTPUT_DIR = Path("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/행정구역별 생활인구")

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

START_YM = "202306"
END_YM = "202605"

age_groups = {
    "0대": ["0세부터9세"],
    "10대": ["10세부터14세", "15세부터19세"],
    "20대": ["20세부터24세", "25세부터29세"],
    "30대": ["30세부터34세", "35세부터39세"],
    "40대": ["40세부터44세", "45세부터49세"],
    "50대": ["50세부터54세", "55세부터59세"],
    "60대": ["60세부터64세", "65세부터69세"],
    "70대이상": ["70세이상"],
}

base_cols = ["기준일ID", "시간대구분", "행정동코드", "총생활인구수"]


def get_yyyymm(file_path):
    match = re.search(r"(\d{6})", file_path.stem)
    return match.group(1) if match else None


def read_csv_safely(file_path):
    try:
        with open(file_path, encoding="utf-8-sig", newline="") as f:
            header = next(csv.reader(f))

        df = pd.read_csv(
            file_path,
            encoding="utf-8-sig",
            usecols=range(len(header)),
            dtype={
                "기준일ID": "string",
                "시간대구분": "string",
                "행정동코드": "string",
            },
            index_col=False,
        )

    except UnicodeDecodeError:
        with open(file_path, encoding="cp949", newline="") as f:
            header = next(csv.reader(f))

        df = pd.read_csv(
            file_path,
            encoding="cp949",
            usecols=range(len(header)),
            dtype={
                "기준일ID": "string",
                "시간대구분": "string",
                "행정동코드": "string",
            },
            index_col=False,
        )

    return df


def convert_5age_to_10age(df):

    out = df[base_cols].copy()

    for gender in ["남자", "여자"]:
        for age_label, parts in age_groups.items():
            cols = [f"{gender}{part}생활인구수" for part in parts]

            missing = [c for c in cols if c not in df.columns]
            if missing:
                raise KeyError(f"없는 컬럼이 있습니다: {missing}")

            out[f"{gender}{age_label}생활인구수"] = (
                df[cols]
                .apply(pd.to_numeric, errors="coerce")
                .sum(axis=1)
            )

    for age_label in age_groups.keys():
        out[f"{age_label}생활인구수"] = (
            out[f"남자{age_label}생활인구수"] +
            out[f"여자{age_label}생활인구수"]
        )

    return out

# %%
files = sorted(INPUT_DIR.glob("LOCAL_PEOPLE_DONG_*.csv"))

print(f"찾은 CSV 파일 수: {len(files)}개")

processed_count = 0
skipped_count = 0
for_file_error = []

for file_path in files:
    yyyymm = get_yyyymm(file_path)


    if yyyymm is None:
        print(f"연월 확인 불가 → 건너뜀: {file_path.name}")
        skipped_count += 1
        continue


    if not (START_YM <= yyyymm <= END_YM):
        print(f"기간 밖 파일 → 건너뜀: {file_path.name}")
        skipped_count += 1
        continue

    print(f"처리 중: {file_path.name}")

    try:
        df = read_csv_safely(file_path)
        converted = convert_5age_to_10age(df)

        output_path = OUTPUT_DIR / f"{file_path.stem}_age10.csv"
        converted.to_csv(output_path, index=False, encoding="utf-8-sig")

        processed_count += 1
        print(f"저장 완료: {output_path.name}")

    except Exception as e:
        print(f"오류 발생: {file_path.name}")
        print(e)
        for_file_error.append(file_path.name)

print("=" * 50)
print("전체 변환 완료")
print(f"처리 완료 파일 수: {processed_count}개")
print(f"건너뛴 파일 수: {skipped_count}개")
print(f"오류 파일 수: {len(for_file_error)}개")
print(f"저장 위치: {OUTPUT_DIR}")

if for_file_error:
    print("오류 발생 파일 목록:")
    for name in for_file_error:
        print("-", name)
# Out:
# 찾은 CSV 파일 수: 36개
# 처리 중: LOCAL_PEOPLE_DONG_202306.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202306_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202307.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202307_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202308.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202308_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202309.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202309_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202310.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202310_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202311.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202311_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202312.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202312_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202401.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202401_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202402.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202402_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202403.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202403_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202404.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202404_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202405.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202405_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202406.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202406_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202407.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202407_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202408.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202408_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202409.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202409_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202410.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202410_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202411.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202411_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202412.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202412_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202501.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202501_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202502.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202502_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202503.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202503_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202504.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202504_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202505.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202505_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202506.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202506_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202507.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202507_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202508.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202508_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202509.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202509_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202510.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202510_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202511.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202511_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202512.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202512_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202601.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202601_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202602.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202602_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202603.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202603_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202604.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202604_age10.csv
# 처리 중: LOCAL_PEOPLE_DONG_202605.csv
# 저장 완료: LOCAL_PEOPLE_DONG_202605_age10.csv
# ==================================================
# 전체 변환 완료
# 처리 완료 파일 수: 36개
# 건너뛴 파일 수: 0개
# 오류 파일 수: 0개
# 저장 위치: /content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/행정구역별 생활인구

# %%
target_file = INPUT_DIR / "LOCAL_PEOPLE_DONG_202509.csv"

print("처리할 파일:", target_file)

df = read_csv_safely(target_file)
converted = convert_5age_to_10age(df)

output_path = OUTPUT_DIR / f"{target_file.stem}_age10.csv"
converted.to_csv(output_path, index=False, encoding="utf-8-sig")

print("저장 완료:", output_path)
# Out:
# 처리할 파일: /content/drive/MyDrive/ESAA YB 4조/주영/행정구역별 시간대 연령대 성별 유동인구/LOCAL_PEOPLE_DONG_202509.csv
# 저장 완료: /content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/행정구역별 생활인구/LOCAL_PEOPLE_DONG_202509_age10.csv

# %% [markdown]
# #전처리
# ### 결측치 및 이상치 정리

# %% [markdown]
# * IQR 기준으로 이상치를 탐지하였으나, 대출건수의 크거나 작은 값은 실제 수요를 반영한 값이므로 제거하지 않음

# %% [markdown]
# 1. 강남구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강남구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강남구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 2. 강동구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강동구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강동구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/1681172190.py:18: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 3. 강북구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강북구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강북구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 4. 강서구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강서구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강서구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 5. 관악구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_관악구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_관악구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/3898506650.py:18: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 6. 광진구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_광진구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_광진구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/1987515667.py:18: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 7. 구로구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_구로구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_구로구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 8. 금천구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_금천구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_금천구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 9. 노원구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_노원구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_노원구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/1162538288.py:18: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 10. 도봉구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_도봉구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_도봉구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/3938910419.py:18: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 11. 동대문구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_동대문구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_동대문구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 12. 동작구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_동작구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_동작구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 13. 마포구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_마포구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_마포구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/1890748569.py:18: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 14. 서대문구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_서대문구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_서대문구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 15. 서초구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_서초구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_서초구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/1568083702.py:18: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 16. 성동구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_성동구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_성동구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/2443001477.py:18: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 17. 성북구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_성북구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_성북구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 18. 송파구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_송파구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_송파구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/2469592785.py:18: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 19. 양천구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_양천구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_양천구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 20. 영등포구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_영등포구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_영등포구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 21. 용산구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_용산구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_용산구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 22. 은평구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_은평구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_은평구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 23. 종로구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_종로구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_종로구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# 24. 중구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_중구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_중구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/570169460.py:18: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# 25. 중랑구

# %%
import pandas as pd
import numpy as np

input_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_중랑구.csv'
output_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_중랑구_전처리.csv'

target_columns = [
    '도서명',
    '저자',
    '출판사',
    '권',
    '주제분류번호',
    '도서권수',
    '대출건수'
]

try:
    df = pd.read_csv(input_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(input_path, encoding='cp949')

df.columns = df.columns.str.strip()

available_target = [c for c in target_columns if c in df.columns]
df = df[available_target].copy()

df = df.dropna(subset=['도서명'])
df = df[df['도서명'].astype(str).str.strip() != '']

fill_values = {
    '저자': '저자미상',
    '출판사': '출판사없음',
    '주제분류번호': '미분류'
}

for col, value in fill_values.items():
    if col in df.columns:
        df[col] = df[col].fillna(value).astype(str).str.strip()
        df[col] = df[col].replace('', value)

if '권' in df.columns:
    df['권'] = df['권'].astype(str).replace('nan', '').str.strip()

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        df = df[df[col] >= 0]

# IQR 기반 이상치 탐지

for col in ['도서권수', '대출건수']:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        _ = df[(df[col] < lower) | (df[col] > upper)]

df = df.drop_duplicates()

df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# /tmp/ipykernel_1521/4267489053.py:18: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, encoding='utf-8')

# %% [markdown]
# #EDA

# %% [markdown]
# ##1. 도서관별 장서 규모 비교
# - 대표 도서관 선정 코드에서 [도서관명], [총자료수]를 추출해 '서울시_도서관_총자료수.csv' 파일로 만듦

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/대표도서관_총자료수/서울시_도서관_총자료수.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1361/3389013892.py in <cell line: 0>()
#       6 plt.rcParams['axes.unicode_minus'] = False
#       7
# ----> 8 df = pd.read_csv('/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/대표도서관_총자료수/서울시_도서관_총자료수.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/대표도서관_총자료수/서울시_도서관_총자료수.csv'

# %% [markdown]
# - 기술통계 확인

# %%
df['총 자료수'].describe()
# Out:
# count        25.000000
# mean     153659.960000
# std       74215.725588
# min       44784.000000
# 25%       87758.000000
# 50%      161366.000000
# 75%      208830.000000
# max      321873.000000
# Name: 총 자료수, dtype: float64

# %% [markdown]
# - 도서관별 장서 규모(막대그래프)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"

fm.fontManager.addfont(font_path)
font_name = fm.FontProperties(fname=font_path).get_name()

plt.rcParams["font.family"] = font_name
plt.rcParams["axes.unicode_minus"] = False

# %%
df = df.sort_values('총 자료수', ascending=False)

plt.figure(figsize=(10,8))

sns.barplot(
    data=df,
    y='도서관명',
    x='총 자료수'
)

plt.title('대표 도서관별 총 자료수')
plt.xlabel('총 자료수')
plt.ylabel('도서관명')

plt.show()

# %% [markdown]
# - 장서 규모를 구간별로 나누어 시각화

# %%
bins = [0, 100000, 150000, 200000, 250000, 350000]
labels = ['10만 미만', '10~15만', '15~20만', '20~25만', '25만 이상']

df['장서 규모'] = pd.cut(df['총 자료수'], bins=bins, labels=labels)

plt.figure(figsize=(7,5))

sns.countplot(data=df, x='장서 규모')

plt.title('대표 도서관 장서 규모 구간별 분포')
plt.xlabel('장서 규모')
plt.ylabel('도서관 수')

plt.show()

# %% [markdown]
# ## 2. 자치구별 독서 성향 및 인기 주제 파악

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. 강남구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강남구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)
# Out:
# /tmp/ipykernel_2293/3091379107.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강남구_전처리.csv")

# %%
genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      14003557
# 자연과학     3159072
# 사회과학     2328336
# 역사       2202213
# 언어       1861924
# 기술과학     1165217
# 예술       1045229
# 철학        641219
# 총류        484049
# 종교        366062
# 미분류            0
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("강남구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 2. 강동구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강동구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# /tmp/ipykernel_1521/552971379.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강동구_전처리.csv")
# 주제
# 문학      8209364
# 언어      2344518
# 사회과학    1539385
# 자연과학    1373719
# 역사      1274215
# 기술과학     652841
# 철학       449423
# 예술       441495
# 종교       277224
# 총류        41829
# 미분류           0
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("강동구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 3. 강북구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강북구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      6399457
# 미분류     1472854
# 사회과학    1445902
# 언어      1306661
# 역사      1175789
# 자연과학    1106514
# 철학       621460
# 기술과학     587711
# 예술       376886
# 총류       321880
# 종교       220568
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("강북구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 4. 강서구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_강서구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      6577713
# 사회과학    1456171
# 역사      1058466
# 자연과학     784772
# 철학       479041
# 기술과학     436400
# 언어       313195
# 총류       277037
# 예술       234964
# 종교       186379
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("강서구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 5. 관악구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_관악구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      6120045
# 사회과학    1627433
# 역사       901019
# 자연과학     779084
# 언어       709538
# 철학       647810
# 기술과학     607623
# 총류       423574
# 예술       401920
# 종교       262354
# 미분류        1141
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("관악구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 6. 광진구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_광진구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# /tmp/ipykernel_1521/4203353165.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_광진구_전처리.csv")
# 주제
# 문학      21731374
# 자연과학     4685556
# 사회과학     4537094
# 역사       3891992
# 언어       2617679
# 예술       2002490
# 기술과학     1686191
# 총류       1655890
# 철학       1383833
# 종교        883737
# 미분류          940
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("광진구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 7. 구로구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_구로구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      557019
# 사회과학    126570
# 자연과학     80514
# 역사       74727
# 기술과학     55674
# 언어       53206
# 철학       44559
# 총류       24540
# 종교       22054
# 예술       20597
# 미분류         20
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("구로구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 8. 금천구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_금천구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      2185206
# 사회과학     686834
# 자연과학     516708
# 역사       400388
# 언어       368793
# 기술과학     277189
# 철학       204276
# 예술       143038
# 종교       115201
# 미분류        1838
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("금천구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 9. 노원구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_노원구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# /tmp/ipykernel_1521/3643645898.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_노원구_전처리.csv")
# 주제
# 문학      16860873
# 사회과학     4126972
# 자연과학     2395426
# 역사       2081080
# 기술과학     1779644
# 언어       1696197
# 철학       1313590
# 예술       1084952
# 종교        579076
# 총류        504170
# 미분류            1
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("노원구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 10. 도봉구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_도봉구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      12111234
# 사회과학     2767853
# 자연과학     1811418
# 역사       1761669
# 기술과학     1320923
# 철학       1069979
# 언어       1004766
# 미분류       846620
# 예술        717528
# 총류        551369
# 종교        421979
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("도봉구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 11. 동대문구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_동대문구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      1668811
# 사회과학     667502
# 역사       331100
# 기술과학     266401
# 자연과학     240974
# 언어       217082
# 철학       209726
# 총류       188699
# 예술       175322
# 종교        93777
# 미분류       12505
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("동대문구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 12. 동작구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_동작구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# /tmp/ipykernel_1521/1563904532.py:1: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_동작구_전처리.csv")
# 주제
# 문학      5597239
# 사회과학     986041
# 자연과학     716741
# 역사       704195
# 기술과학     421560
# 철학       366101
# 언어       353798
# 종교       197213
# 예술       172276
# 미분류           0
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("동작구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 13. 마포구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_마포구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# /tmp/ipykernel_1521/2143945308.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_마포구_전처리.csv")
# 주제
# 문학      21510028
# 사회과학     4608552
# 자연과학     3940677
# 역사       3266167
# 기술과학     2031435
# 예술       1932876
# 언어       1722153
# 철학       1570770
# 총류       1132320
# 종교        545118
# 미분류        89548
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("마포구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 14. 서대문구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_서대문구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      6625547
# 사회과학    1257192
# 자연과학     847011
# 역사       837728
# 기술과학     385037
# 언어       363750
# 예술       274790
# 철학       226753
# 총류       212951
# 종교       128470
# 미분류           0
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("서대문구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 15. 서초구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_서초구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# /tmp/ipykernel_1521/3700449616.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_서초구_전처리.csv")
# 주제
# 문학      23056002
# 사회과학     3134834
# 자연과학     2877406
# 역사       2453813
# 언어       1743009
# 기술과학     1332787
# 철학       1001306
# 예술        739188
# 총류        637735
# 종교        305864
# 미분류       217590
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("서초구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 16. 성동구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_성동구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      13908329
# 언어       2722578
# 사회과학     2648005
# 자연과학     2289855
# 역사       2046940
# 종교       1005606
# 기술과학      994512
# 철학        862684
# 예술        699520
# 총류        405171
# 미분류            0
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("성동구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 17. 성북구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_성북구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      4117311
# 사회과학     939371
# 자연과학     564772
# 미분류      526762
# 역사       513275
# 언어       434121
# 철학       324363
# 기술과학     308152
# 예술       177899
# 총류       159572
# 종교       144663
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("성북구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 18. 송파구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_송파구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# /tmp/ipykernel_1521/2824270838.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_송파구_전처리.csv")
# 주제
# 문학      11077376
# 자연과학     3094136
# 언어       2906985
# 역사       2238875
# 사회과학     2146324
# 예술       1559619
# 기술과학      925106
# 철학        499891
# 종교        267108
# 총류        133520
# 미분류         2688
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("송파구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 19. 양천구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_양천구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# /tmp/ipykernel_1521/149548005.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_양천구_전처리.csv")
# 주제
# 문학      3157338
# 자연과학     629312
# 사회과학     610107
# 역사       375614
# 언어       361803
# 기술과학     282601
# 철학       171548
# 예술       121635
# 종교       117525
# 총류        43144
# 미분류           4
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("양천구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 20. 영등포구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_영등포구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      9890894
# 사회과학    1955583
# 자연과학    1540675
# 역사      1326032
# 언어      1139921
# 기술과학     638408
# 철학       552475
# 총류       336071
# 예술       287049
# 종교       151772
# 미분류         195
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("영등포구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 21. 용산구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_용산구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      277126
# 사회과학     75973
# 역사       43689
# 자연과학     30376
# 철학       29017
# 기술과학     24746
# 언어       13713
# 예술        9107
# 종교        4515
# 미분류         71
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("용산구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 22. 은평구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_은평구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      7382237
# 사회과학    1777319
# 자연과학    1540984
# 언어      1300464
# 역사      1071903
# 기술과학     612044
# 철학       576392
# 예술       407451
# 총류       387833
# 종교       291811
# 미분류        7961
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("은평구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 23. 종로구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_종로구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      7545537
# 사회과학    2264102
# 역사      1327645
# 자연과학    1139180
# 기술과학     981712
# 철학       947552
# 예술       941393
# 언어       778762
# 미분류      626873
# 총류       537763
# 종교       350695
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("종로구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 24. 중구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_중구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# /tmp/ipykernel_1521/466181577.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_중구_전처리.csv")
# 주제
# 문학      1450913
# 사회과학     330966
# 자연과학     208683
# 역사       203886
# 언어       191813
# 기술과학     147369
# 철학        97817
# 예술        66906
# 종교        37202
# 총류        21582
# 미분류           1
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("중구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# 25. 중랑구

# %%
df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_중랑구_전처리.csv")

df['주제분류번호'] = df['주제분류번호'].astype(str)

df['대분류'] = df['주제분류번호'].apply(
    lambda x: '미분류' if x == '미분류' else x[0]
)

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

df['주제'] = df['대분류'].map(kdc)

genre = (
    df.groupby('주제')['대출건수']
      .sum()
      .sort_values(ascending=False)
)

genre
# Out:
# 주제
# 문학      13948807
# 사회과학     3080093
# 자연과학     1870066
# 역사       1656644
# 기술과학      963225
# 철학        893326
# 언어        718394
# 예술        419483
# 종교        233190
# 총류        182336
# 미분류       126464
# Name: 대출건수, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=genre.values,
    y=genre.index
)

plt.title("중량구 인기 주제")
plt.xlabel("대출건수")
plt.ylabel("주제")

plt.show()

# %% [markdown]
# ## 3. 주제별 장기 미대출 비율 분석
# - 주제별 대출 비율(%) = (해당 주제의 총 대출건수 ÷ 전체 주제의 총 대출건수) × 100
# - 히트맵 시각화

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - R_{g,i} : 자치구 g의 주제 i 대출 비율(%)
#
# - T_{g,i} : 자치구 g의 주제 i 총 대출건수
#
# - K : KDC 대분류 개수(11개)
#
# - Σ_{k=1}^{K} T_{g,k} : 자치구 g의 전체 대출건수

# %%
import pandas as pd
import os
import glob

folder = "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_전처리"
files = glob.glob(os.path.join(folder, "*.csv"))

for file in files:

    filename = os.path.basename(file)
    parts = filename.replace(".csv", "").split("_")
    gu = parts[1]

    try:
        df = pd.read_csv(
            file,
            dtype={"주제분류번호": str},
            low_memory=False
        )
    except pd.errors.EmptyDataError:
        print(f"{filename} -> 빈 파일이라 제외")
        continue

# %%
import pandas as pd
import glob
import os

folder = "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_전처리"

files = glob.glob(os.path.join(folder, "*.csv"))

kdc = {
    '0':'총류',
    '1':'철학',
    '2':'종교',
    '3':'사회과학',
    '4':'자연과학',
    '5':'기술과학',
    '6':'예술',
    '7':'언어',
    '8':'문학',
    '9':'역사',
    '미분류':'미분류'
}

result = []

for file in files:

    filename = os.path.basename(file)
    parts = filename.replace(".csv", "").split("_")
    gu = parts[1]

    try:
        df = pd.read_csv(
            file,
            dtype={"주제분류번호": str},
            low_memory=False
        )
    except pd.errors.EmptyDataError:
        print(f"{filename} -> 빈 파일이라 제외")
        continue

    df["주제분류번호"] = df["주제분류번호"].astype(str)

    df["대분류"] = df["주제분류번호"].apply(
        lambda x: "미분류" if x == "미분류" else x[0]
    )

    df["주제"] = df["대분류"].map(kdc)

    genre = df.groupby("주제")["대출건수"].sum()

    genre_ratio = (genre / genre.sum() * 100).round(2)

    row = {"자치구": gu}

    for subject, value in genre_ratio.items():
        row[subject] = value

    result.append(row)

final = pd.DataFrame(result)

final = final.fillna(0)

# %%
column_order = [
    "자치구",
    "총류",
    "철학",
    "종교",
    "사회과학",
    "자연과학",
    "기술과학",
    "예술",
    "언어",
    "문학",
    "역사",
    "미분류"
]

final = final[column_order]

gu_order = [
    '강남구','강동구','강북구','강서구','관악구',
    '광진구','구로구','금천구','노원구','도봉구',
    '동대문구','동작구','마포구','서대문구','서초구',
    '성동구','성북구','송파구','양천구','영등포구',
    '용산구','은평구','종로구','중구','중랑구'
]

# %%
final = pd.DataFrame(result)

column_order = [
    "자치구","총류","철학","종교","사회과학","자연과학",
    "기술과학","예술","언어","문학","역사","미분류"
]

final = final.fillna(0)

final = final.reindex(columns=column_order)

display(final)
# Out:
#            자치구    총류    철학    종교   사회과학   자연과학  기술과학    예술     언어     문학  \
# 0     강남구  1.78  2.35  1.34   8.54  11.59  4.27  3.83   6.83  51.37
# 1     강동구  0.31  2.70  1.65   9.32   8.34  3.92  2.65  14.04  49.38
# 2     강북구  2.14  4.13  1.47   9.62   7.36  3.91  2.51   8.69  42.56
# 3      강서구  2.35  4.06  1.58  12.34   6.65  3.70  1.99   2.65  55.72
# 4     관악구  3.39  5.19  2.10  13.04   6.25  4.86  3.22   5.68  49.03
# 5       구로구  2.32  4.21  2.08  11.95   7.60  5.25  1.94   5.02  52.57
# 6     금천구  0.00  4.17  2.35  14.02  10.55  5.66  2.92   7.53  44.60
# 7      노원구  1.71  4.04  1.77  12.71   7.36  5.45  3.35   5.23  51.97
# 8      도봉구  2.26  4.39  1.73  11.35   7.43  5.42  2.94   4.12  49.67
# 9   동대문구  4.63  5.15  2.30  16.39   5.92  6.54  4.31   5.33  40.98
# 10    동작구  0.00  3.85  2.07  10.36   7.53  4.43  1.81   3.72  58.82
# 11      마포구  2.67  3.71  1.29  10.88   9.31  4.80  4.56   4.07  50.79
# 12   서대문구  1.91  2.03  1.15  11.27   7.59  3.45  2.46   3.26  59.37
# 13      서초구  1.70  2.67  0.82   8.36   7.67  3.55  1.97   4.65  61.48
# 14    성동구  1.47  3.13  3.65   9.60   8.30  3.61  2.54   9.87  50.42
# 15    성북구  1.94  3.95  1.76  11.44   6.88  3.75  2.17   5.29  50.15
# 16     송파구  0.54  2.01  1.07   8.64  12.45  3.72  6.28  11.70  44.57
# 17    양천구  0.95  2.89  1.99  10.36  10.69  4.78  2.07   6.16  53.72
# 18  영등포구  1.89  3.10  0.85  10.97   8.65  3.58  1.61   6.40  55.51
# 19    용산구  0.00  5.71  0.89  14.95   5.98  4.87  1.79   2.70  54.52
# 20    은평구  2.53  3.75  1.90  11.57  10.03  3.99  2.65   8.47  48.07
# 21     종로구  3.08  5.43  2.01  12.98   6.53  5.63  5.40   4.47  43.26
# 22       중구  1.46  3.46  1.25  11.76   7.50  5.21  2.43   6.95  52.59
# 23    중랑구  0.76  3.71  0.97  12.78   7.76  4.00  1.74   2.98  57.90
# 24    광진구  3.68  2.98  2.08   9.86  10.57  3.62  4.57   5.83  48.16
#
#       역사   미분류
# 0   8.08  0.00
# 1   7.67  0.00
# 2   7.82  9.80
# 3   8.97  0.00
# 4   7.22  0.01
# 5   7.05  0.00
# 6   8.17  0.04
# 7   6.42  0.00
# 8   7.22  3.47
# 9   8.13  0.31
# 10  7.40  0.00
# 11  7.71  0.21
# 12  7.51  0.00
# 13  6.54  0.58
# 14  7.42  0.00
# 15  6.25  6.42
# 16  9.01  0.01
# 17  6.40  0.00
# 18  7.44  0.00
# 19  8.59  0.01
# 20  6.98  0.05
# 21  7.61  3.59
# 22  7.39  0.00
# 23  6.88  0.52
# 24  8.64  0.00

# %%
subject_cols = column_order[1:]

final["합계"] = final[subject_cols].sum(axis=1)

print(final[["자치구", "합계"]])
# Out:
#            자치구      합계
# 0     강남구   99.98
# 1     강동구   99.98
# 2     강북구  100.01
# 3      강서구  100.01
# 4     관악구   99.99
# 5       구로구   99.99
# 6     금천구  100.01
# 7      노원구  100.01
# 8      도봉구  100.00
# 9   동대문구   99.99
# 10    동작구   99.99
# 11      마포구  100.00
# 12   서대문구  100.00
# 13      서초구   99.99
# 14    성동구  100.01
# 15    성북구  100.00
# 16     송파구  100.00
# 17    양천구  100.01
# 18  영등포구  100.00
# 19    용산구  100.01
# 20    은평구   99.99
# 21     종로구   99.99
# 22       중구  100.00
# 23    중랑구  100.00
# 24    광진구   99.99

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import unicodedata

final['자치구'] = final['자치구'].apply(lambda x: unicodedata.normalize('NFC', str(x)))
final.columns = final.columns.map(lambda x: unicodedata.normalize('NFC', str(x)))

plt.figure(figsize=(12, 10))

sns.heatmap(
    final.set_index('자치구'),
    annot=True,
    fmt=".1f",
    cmap="YlGnBu",
    linewidths=0.5
)

plt.title("자치구별 KDC 주제별 대출 비율")
plt.xlabel("주제")
plt.ylabel("자치구")

plt.tight_layout()
plt.show()

# %%
output_path = "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/주제수요점수.csv"

final.to_csv(
    output_path,
    index=False,
    encoding="utf-8-sig"
)

print("저장 완료")
# Out:
# 저장 완료

# %% [markdown]
# ## 4. 자치구별 인당 장서수

# %% [markdown]
# (인당 장서수=총 장서수/인구)로 계산하여 구별로 도서 부족 가능성 비교

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"

fm.fontManager.addfont(font_path)
font_name = fm.FontProperties(fname=font_path).get_name()

plt.rcParams["font.family"] = font_name
plt.rcParams["axes.unicode_minus"] = False

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# !pip install adjustText
from adjustText import adjust_text

pop_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/행정구역별 생활인구/LOCAL_PEOPLE_DONG_202605_age10.csv'
book_path = '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/대표도서관_총자료수/서울시_도서관_총자료수.csv'

seoul_gu_dict = {
    '11110': '종로구', '11140': '중구', '11170': '용산구', '11200': '성동구',
    '11215': '광진구', '11230': '동대문구', '11260': '중랑구', '11290': '성북구',
    '11305': '강북구', '11320': '도봉구', '11350': '노원구', '11380': '은평구',
    '11410': '서대문구', '11440': '마포구', '11470': '양천구', '11500': '강서구',
    '11530': '구로구', '11545': '금천구', '11560': '영등포구', '11590': '동작구',
    '11620': '관악구', '11650': '서초구', '11680': '강남구', '11710': '송파구',
    '11740': '강동구'
}

seoul_gus_ganada = [
    '강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구',
    '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구',
    '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'
]

try:
    df_pop = pd.read_csv(pop_path, encoding='utf-8')
except UnicodeDecodeError:
    df_pop = pd.read_csv(pop_path, encoding='cp949')

df_pop.columns = df_pop.columns.str.strip()
pop_col_name = next((col for col in df_pop.columns if '총생활인구' in col), df_pop.columns[3])
df_pop = df_pop.rename(columns={pop_col_name: '총생활인구'})

df_pop['행정동코드'] = df_pop['행정동코드'].astype(str).str.strip()
df_pop['자치구'] = df_pop['행정동코드'].str[:5].map(seoul_gu_dict)
df_pop = df_pop.dropna(subset=['자치구'])
df_pop['총생활인구'] = pd.to_numeric(df_pop['총생활인구'], errors='coerce').fillna(0)

df_pop_grouped = df_pop.groupby(['자치구', '기준일ID'])['총생활인구'].sum().reset_index()
df_pop_final = df_pop_grouped.groupby('자치구')['총생활인구'].mean().reset_index(name='인구수')

try:
    df_book = pd.read_csv(book_path, encoding='utf-8')
except UnicodeDecodeError:
    df_book = pd.read_csv(book_path, encoding='cp949')

df_book.columns = df_book.columns.str.strip()
df_book = df_book.head(25).copy()
df_book['자치구'] = seoul_gus_ganada
df_book_final = df_book.groupby('자치구')['총 자료수'].sum().reset_index(name='총장서수')

df_analysis = pd.merge(df_pop_final, df_book_final, on='자치구', how='inner')
df_analysis['인당장서수'] = df_analysis['총장서수'] / df_analysis['인구수']

X = sm.add_constant(df_analysis['인구수'])
model = sm.OLS(df_analysis['총장서수'], X).fit()
df_analysis['predict'] = model.predict(X)

fig, ax = plt.subplots(figsize=(14, 9))
sns.regplot(
    data=df_analysis,
    x='인구수',
    y='총장서수',
    scatter_kws={'s': 120, 'color': 'dodgerblue', 'alpha': 0.7},
    line_kws={'color': 'crimson', 'linestyle': '--', 'linewidth': 2},
    ax=ax
)

texts = []
for i in range(df_analysis.shape[0]):
    x_val = df_analysis['인구수'].iloc[i]
    y_val = df_analysis['총장서수'].iloc[i]
    gu_name = df_analysis['자치구'].iloc[i]

    text_color = 'red' if y_val < df_analysis['predict'].iloc[i] else 'black'
    weight = 'bold' if y_val < df_analysis['predict'].iloc[i] else 'normal'

    texts.append(
        ax.text(
            x_val,
            y_val,
            gu_name,
            fontsize=11,
            color=text_color,
            weight=weight
        )
    )

adjust_text(
    texts,
    ax=ax,
    arrowprops=dict(arrowstyle='-', color='gray', lw=0.7)
)

ax.set_title('서울시 자치구별 인구수 대비 장서 규모 (회귀선 아래 = 도서 부족 위험 구)', fontsize=16, pad=20, weight='bold')
ax.set_xlabel('평균 생활인구 수 (명)', fontsize=12, labelpad=10)
ax.set_ylabel('총 장서 수 (권)', fontsize=12, labelpad=10)
ax.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: adjustText in /usr/local/lib/python3.12/dist-packages (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from adjustText) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from adjustText) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from adjustText) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->adjustText) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->adjustText) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->adjustText) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->adjustText) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->adjustText) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->adjustText) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1361/4146507718.py in <cell line: 0>()
#      46
#      47 try:
# ---> 48     df_book = pd.read_csv(book_path, encoding='utf-8')
#      49 except UnicodeDecodeError:
#      50     df_book = pd.read_csv(book_path, encoding='cp949')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/대표도서관_총자료수/서울시_도서관_총자료수.csv'

# %% [markdown]
# ## 5. 대출 회전율 분석

# %% [markdown]
# *   (회전율=대출건수/장서 수)으로 계산
# *   책은 많은데 수요가 많은 도서관, 수요 대비 장서가 부족한 도서관 구분

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울시_도서관_총대출수.csv")

df["총 대출수"] = pd.to_numeric(df["총 대출수"], errors="coerce")
df["총 자료수"] = pd.to_numeric(df["총 자료수"], errors="coerce")

df["회전율"] = df["총 대출수"] / df["총 자료수"]

df = df.dropna(subset=["총 대출수", "총 자료수"]).reset_index(drop=True)

districts = [
    "강남구","강동구","강북구","강서구","관악구",
    "광진구","구로구","금천구","노원구","도봉구",
    "동대문구","동작구","마포구","서대문구","서초구",
    "성동구","성북구","송파구","양천구","영등포구",
    "용산구","은평구","종로구","중구","중랑구"
]

plt.figure(figsize=(10, 8))

scatter = plt.scatter(
    df["총 자료수"],
    df["총 대출수"],
    c=df["회전율"],
    cmap="RdYlGn",
    s=120,
    edgecolors="black"
)

for i, row in df.iterrows():
    plt.text(
        row["총 자료수"],
        row["총 대출수"],
        districts[i],
        fontsize=9,
        ha="left",
        va="bottom"
    )

plt.axvline(df["총 자료수"].mean(), color="red", linestyle="--", linewidth=1.2)
plt.axhline(df["총 대출수"].mean(), color="red", linestyle="--", linewidth=1.2)

plt.text(
    df["총 자료수"].min(),
    df["총 대출수"].max(),
    "장서 부족\n(수요 높음)",
    fontsize=10,
    fontweight="bold"
)

plt.text(
    df["총 자료수"].max(),
    df["총 대출수"].min(),
    "장서 과다\n(수요 낮음)",
    fontsize=10,
    ha="right",
    fontweight="bold"
)

plt.xlabel("장서수")
plt.ylabel("대출건수")
plt.title("서울시 자치구 대표도서관 장서수-대출건수 산점도")

plt.colorbar(scatter, label="회전율(대출건수/장서수)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. 도서관별 KDC 주제별 소장권수 비교

# %%
import pandas as pd
import matplotlib.pyplot as plt

try:
    df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/도서관별 주제별 소장권수.csv", encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/도서관별 주제별 소장권수.csv", encoding='cp949')

print(df.head())
print(df.info())
# Out:
#    도서관     총류     철학     종교    사회과학   자연과학   기술과학     예술     언어      문학  \
# 0  종로구  24068  26851  16690  110793  22250  51864  29997  15189  133763
# 1   중구   2434   4112   1277   11836   5211   6337   3598   2972   40819
# 2  용산구   1352   2769    820    7164   3031   3170   1575    922   19467
# 3  성동구   8526  11083   4797   33612  12685  15220   7925   4825   70489
# 4  광진구  17245  16893   6959   53921  18899  23910  15924  11216  123291
#
#       역사      합계
# 0  49101  480296
# 1   4978   83574
# 2   3140   43410
# 3  16577  185739
# 4  22402  310660
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   도서관     25 non-null     object
#  1   총류      25 non-null     int64
#  2   철학      25 non-null     int64
#  3   종교      25 non-null     int64
#  4   사회과학    25 non-null     int64
#  5   자연과학    25 non-null     int64
#  6   기술과학    25 non-null     int64
#  7   예술      25 non-null     int64
#  8   언어      25 non-null     int64
#  9   문학      25 non-null     int64
#  10  역사      25 non-null     int64
#  11  합계      25 non-null     int64
# dtypes: int64(11), object(1)
# memory usage: 2.5+ KB
# None

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore', category=UserWarning, module='matplotlib')

df = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/도서관별 주제별 소장권수.csv", encoding='cp949')
subjects = ['총류', '철학', '종교', '사회과학', '자연과학', '기술과학', '예술', '언어', '문학', '역사']

for sub in subjects:
    df_sorted = df.sort_values(by=sub, ascending=False)

    plt.figure(figsize=(16, 8))

    plt.rcParams['font.family'] = 'NanumGothic'

    ax = sns.barplot(x='도서관', y=sub, data=df_sorted, palette='viridis')

    for p in ax.patches:
        ax.annotate(f'{int(p.get_height()):,}',
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center',
                    xytext=(0, 8),
                    textcoords='offset points',
                    fontsize=9, weight='bold')

    plt.title(f'25개 자치구 도서관별 {sub} 소장권수 비교', fontsize=16, weight='bold', pad=20)
    plt.xlabel('도서관 (자치구)', fontsize=12)
    plt.ylabel('소장권수 (권)', fontsize=12)
    plt.xticks(rotation=45)
    plt.ylim(0, df_sorted[sub].max() * 1.1)
    plt.tight_layout()
    plt.show()
# Out:
# /tmp/ipykernel_1361/3592927660.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='도서관', y=sub, data=df_sorted, palette='viridis')
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 46993 (\N{HANGUL SYLLABLE RANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 48393 (\N{HANGUL SYLLABLE BONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49569 (\N{HANGUL SYLLABLE SONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50501 (\N{HANGUL SYLLABLE AG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46993 (\N{HANGUL SYLLABLE RANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48393 (\N{HANGUL SYLLABLE BONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49569 (\N{HANGUL SYLLABLE SONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50501 (\N{HANGUL SYLLABLE AG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='도서관', y=sub, data=df_sorted, palette='viridis')
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 46993 (\N{HANGUL SYLLABLE RANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 48393 (\N{HANGUL SYLLABLE BONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50501 (\N{HANGUL SYLLABLE AG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49569 (\N{HANGUL SYLLABLE SONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 52384 (\N{HANGUL SYLLABLE CEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1361/3592927660.py:33: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52384 (\N{HANGUL SYLLABLE CEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46993 (\N{HANGUL SYLLABLE RANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48393 (\N{HANGUL SYLLABLE BONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50501 (\N{HANGUL SYLLABLE AG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49569 (\N{HANGUL SYLLABLE SONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.

# %% [markdown]
# #파생변수 생성 및 점수화

# %% [markdown]
# ## 1. Priority Score: 이관 후보 도서 선별

# %% [markdown]
# Priority Score = 0.45 X 장기미대출비율 + 0.30 X (100 - 장서회전율정규화) + 0.25 X (100 - 미래대출지수정규화)

# %%
import unicodedata
import pandas as pd
import os

folder_path = "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_전처리"

kdc_map = {
    0: "총류", 1: "철학", 2: "종교", 3: "사회과학", 4: "자연과학",
    5: "기술과학", 6: "예술", 7: "언어", 8: "문학", 9: "역사"
}

all_gu_list = []

for file in os.listdir(folder_path):
    if not (file.endswith(".xlsx") or file.endswith(".csv")):
        continue

    gu_name = file.replace(".csv", "").replace(".xlsx", "").split("_")[1]
    gu_name = unicodedata.normalize('NFC', gu_name)

    file_path = os.path.join(folder_path, file)
    if file.endswith(".xlsx"):
        df_temp = pd.read_excel(file_path)
    else:
        df_temp = pd.read_csv(file_path, low_memory=False)

    subj = df_temp["주제분류번호"].astype(str)
    is_valid = subj.str[0].str.isdigit()
    df_temp = df_temp[is_valid].copy()

    df_temp["KDC주제"] = (
        df_temp["주제분류번호"].astype(str).str[0].astype(int).map(kdc_map)
    )
    df_temp["자치구"] = gu_name

    all_gu_list.append(df_temp)

df_book_all = pd.concat(all_gu_list, ignore_index=True)

# %%
df_priority = df_book_all.groupby(["자치구", "KDC주제"]).agg(
    총소장권수=("도서권수", "sum"),
    연간대출건수=("대출건수", "sum"),
    장기미대출권수=("대출건수", lambda x: (x == 0).sum())
).reset_index()

# %%
#장기미대출비율
df_gu_summary = df_priority.groupby("자치구").agg(
    총소장권수=("총소장권수", "sum"),
    장기미대출권수=("장기미대출권수", "sum")
).reset_index()

df_gu_summary["장기미대출비율"] = (
    df_gu_summary["장기미대출권수"] /
    df_gu_summary["총소장권수"]
) * 100

df_gu_summary.sort_values("장기미대출비율", ascending=False)
# Out:
#      자치구    총소장권수  장기미대출권수    장기미대출비율
# 20   용산구   101050    19265  19.064819
# 10  동대문구   350199    43950  12.550007
# 7    금천구   383146    37042   9.667855
# 23    중구   227562    21580   9.483130
# 13  서대문구   531726    44674   8.401696
# 16   성북구   404936    32153   7.940267
# 18   양천구   323027    22820   7.064425
# 4    관악구   631797    42746   6.765781
# 21   은평구   697648    46063   6.602613
# 22   종로구  1144788    74861   6.539289
# 6    구로구   104500     6214   5.946411
# 9    도봉구  1213023    67296   5.547793
# 24   중랑구   896513    48928   5.457590
# 12   마포구  1536432    79811   5.194568
# 3    강서구   425696    20227   4.751513
# 5    광진구  1480077    68335   4.616990
# 8    노원구  1255046    47316   3.770061
# 15   성동구  1120908    38412   3.426865
# 1    강동구   533107    18061   3.387875
# 2    강북구   582618    19644   3.371677
# 17   송파구   679033    21818   3.213099
# 0    강남구   857098    21096   2.461329
# 14   서초구  1068512    23410   2.190897
# 11   동작구   385590     6480   1.680542
# 19  영등포구   624298     7612   1.219290

# %%
# 장서회전율 정규화
df_gu_summary = df_priority.groupby("자치구").agg(
    총소장권수=("총소장권수", "sum"),
    연간대출건수=("연간대출건수", "sum"),
    장기미대출권수=("장기미대출권수", "sum")
).reset_index()

df_gu_summary["장기미대출비율"] = (
    df_gu_summary["장기미대출권수"] /
    df_gu_summary["총소장권수"]
) * 100

df_gu_summary["장서회전율"] = (
    df_gu_summary["연간대출건수"] /
    df_gu_summary["총소장권수"]
)

min_turnover_gu = df_gu_summary["장서회전율"].min()
max_turnover_gu = df_gu_summary["장서회전율"].max()

df_gu_summary["장서회전율정규화"] = (
    (df_gu_summary["장서회전율"] - min_turnover_gu)
    / (max_turnover_gu - min_turnover_gu)
) * 100

df_gu_summary.sort_values("장서회전율", ascending=False)
# Out:
#      자치구    총소장권수    연간대출건수  장기미대출권수    장기미대출비율      장서회전율    장서회전율정규화
# 5    광진구  1480077  59260557    68335   4.616990  40.038834  100.000000
# 17   송파구   679033  24848940    21818   3.213099  36.594598   90.161865
# 14   서초구  1068512  37281944    23410   2.190897  34.891460   85.297011
# 0    강남구   857098  27256878    21096   2.461329  31.801355   76.470416
# 1    강동구   533107  16805158    18061   3.387875  31.523049   75.675459
# 19  영등포구   624298  17818880     7612   1.219290  28.542267   67.161135
# 3    강서구   425696  11804138    20227   4.751513  27.729032   64.838206
# 12   마포구  1536432  42260096    79811   5.194568  27.505347   64.199272
# 24   중랑구   896513  23965564    48928   5.457590  26.731976   61.990209
# 8    노원구  1255046  32421980    47316   3.770061  25.833300   59.423226
# 11   동작구   385590   9515164     6480   1.680542  24.676895   56.120064
# 15   성동구  1120908  27583200    38412   3.426865  24.607907   55.923006
# 2    강북구   582618  13562828    19644   3.371677  23.279109   52.127419
# 21   은평구   697648  15348438    46063   6.602613  22.000261   48.474509
# 13  서대문구   531726  11159229    44674   8.401696  20.986803   45.579663
# 4    관악구   631797  12484430    42746   6.765781  19.760192   42.075962
# 9    도봉구  1213023  23538718    67296   5.547793  19.405006   41.061406
# 16   성북구   404936   7683499    32153   7.940267  18.974601   39.831995
# 18   양천구   323027   5870627    22820   7.064425  18.173797   37.544573
# 22   종로구  1144788  16814341    74861   6.539289  14.687733   27.586961
# 7    금천구   383146   4897633    37042   9.667855  12.782681   22.145356
# 23    중구   227562   2757137    21580   9.483130  12.115982   20.240993
# 10  동대문구   350199   4059394    43950  12.550007  11.591678   18.743368
# 6    구로구   104500   1059460     6214   5.946411  10.138373   14.592140
# 20   용산구   101050    508262    19265  19.064819   5.029807    0.000000

# %%
import pandas as pd
import numpy as np
import re
import unicodedata

pop_raw = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울시 주민등록인구및세대현황.csv", encoding="cp949")

seoul_gu = [
    "종로구", "중구", "용산구", "성동구", "광진구",
    "동대문구", "중랑구", "성북구", "강북구", "도봉구",
    "노원구", "은평구", "서대문구", "마포구", "양천구",
    "강서구", "구로구", "금천구", "영등포구", "동작구",
    "관악구", "서초구", "강남구", "송파구", "강동구"
]
pop_raw["자치구"] = pop_raw["행정구역"].astype(str).str.extract(
    "(" + "|".join(seoul_gu) + ")"
)
pop_raw = pop_raw.dropna(subset=["자치구"]).copy()

pop_calc = pop_raw[["자치구", "2024년_총인구수", "2025년_총인구수"]].copy()
for col in ["2024년_총인구수", "2025년_총인구수"]:
    pop_calc[col] = pd.to_numeric(pop_calc[col].astype(str).str.replace(",", ""), errors="coerce")
pop_calc = pop_calc.dropna().copy()
pop_calc["인구증가율"] = (pop_calc["2025년_총인구수"] - pop_calc["2024년_총인구수"]) / pop_calc["2024년_총인구수"] * 100
pop_result = pop_calc[["자치구", "인구증가율"]]

df_households_raw = pop_raw[[
    "자치구",
    "2024년_세대수",
    "2025년_세대수"
]].copy()

for col in ["2024년_세대수", "2025년_세대수"]:
    df_households_raw[col] = pd.to_numeric(df_households_raw[col].astype(str).str.replace(",", ""), errors="coerce")

df_households_raw = df_households_raw.dropna().copy()
df_households_raw["총세대수"] = df_households_raw[["2024년_세대수", "2025년_세대수"]].mean(axis=1).astype(int)
df_households_per_gu = df_households_raw.groupby("자치구")["총세대수"].mean().reset_index()

df_gu_summary['자치구'] = df_gu_summary['자치구'].apply(lambda x: unicodedata.normalize('NFC', str(x)))
pop_result = pop_result.copy()
pop_result['자치구'] = pop_result['자치구'].apply(lambda x: unicodedata.normalize('NFC', str(x)))
df_households_per_gu['자치구'] = df_households_per_gu['자치구'].apply(lambda x: unicodedata.normalize('NFC', str(x)))

base_cols = ['자치구', '총소장권수', '연간대출건수', '장기미대출비율', '장서회전율', '장서회전율정규화']
df_base = df_gu_summary[[c for c in df_gu_summary.columns if c in base_cols]].copy()

df_merged_summary = pd.merge(df_base, pop_result[['자치구', '인구증가율']], on='자치구', how='left')
df_merged_summary = pd.merge(df_merged_summary, df_households_per_gu, on='자치구', how='left')

mean_households = df_merged_summary["총세대수"].mean()
df_merged_summary["미래대출예측량"] = (
    df_merged_summary["연간대출건수"] *
    (1 + (df_merged_summary["인구증가율"] / 100)) *
    (df_merged_summary["총세대수"] / mean_households)
)

min_p = df_merged_summary["미래대출예측량"].min()
max_p = df_merged_summary["미래대출예측량"].max()

df_merged_summary["미래대출지수정규화"] = (
    (df_merged_summary["미래대출예측량"] - min_p)
    / (max_p - min_p)
) * 100

df_gu_summary = df_merged_summary
display(df_gu_summary.sort_values("미래대출지수정규화", ascending=False))
# Out:
#      자치구    총소장권수    연간대출건수    장기미대출비율      장서회전율    장서회전율정규화     인구증가율  \
# 5    광진구  1480077  59260557   4.616990  40.038834  100.000000 -0.239786
# 12   마포구  1536432  42260096   5.194568  27.505347   64.199272 -1.051694
# 17   송파구   679033  24848940   3.213099  36.594598   90.161865 -1.039824
# 8    노원구  1255046  32421980   3.770061  25.833300   59.423226 -1.568661
# 0    강남구   857098  27256878   2.461329  31.801355   76.470416 -0.182113
# 14   서초구  1068512  37281944   2.190897  34.891460   85.297011  1.481968
# 24   중랑구   896513  23965564   5.457590  26.731976   61.990209 -0.621714
# 1    강동구   533107  16805158   3.387875  31.523049   75.675459  4.651509
# 15   성동구  1120908  27583200   3.426865  24.607907   55.923006  0.342384
# 4    관악구   631797  12484430   6.765781  19.760192   42.075962 -0.043322
# 19  영등포구   624298  17818880   1.219290  28.542267   67.161135 -0.645044
# 21   은평구   697648  15348438   6.602613  22.000261   48.474509 -1.254450
# 9    도봉구  1213023  23538718   5.547793  19.405006   41.061406 -1.097854
# 3    강서구   425696  11804138   4.751513  27.729032   64.838206 -1.161513
# 2    강북구   582618  13562828   3.371677  23.279109   52.127419 -1.646350
# 11   동작구   385590   9515164   1.680542  24.676895   56.120064 -1.031136
# 13  서대문구   531726  11159229   8.401696  20.986803   45.579663 -0.893503
# 16   성북구   404936   7683499   7.940267  18.974601   39.831995  0.236977
# 22   종로구  1144788  16814341   6.539289  14.687733   27.586961 -0.931066
# 18   양천구   323027   5870627   7.064425  18.173797   37.544573 -1.366201
# 10  동대문구   350199   4059394  12.550007  11.591678   18.743368  2.215891
# 7    금천구   383146   4897633   9.667855  12.782681   22.145356 -0.830080
# 6    구로구   104500   1059460   5.946411  10.138373   14.592140 -1.118070
# 23    중구   227562   2757137   9.483130  12.115982   20.240993 -2.272199
# 20   용산구   101050    508262  19.064819   5.029807    0.000000 -0.961472
#
#         총세대수       미래대출예측량   미래대출지수정규화
# 5   170532.0  5.611431e+07  100.000000
# 12  180697.0  4.205663e+07   74.818500
# 17  286460.0  3.920820e+07   69.716129
# 8   217151.0  3.857264e+07   68.577650
# 0   245179.0  3.712893e+07   65.991523
# 14  172093.0  3.624059e+07   64.400250
# 24  189017.0  2.505675e+07   44.366651
# 1   217604.0  2.130098e+07   37.638959
# 15  132563.0  2.042189e+07   36.064252
# 4   287370.0  1.996028e+07   35.237361
# 19  192303.0  1.894963e+07   33.426981
# 21  214790.0  1.811926e+07   31.939545
# 9   138888.0  1.799691e+07   31.720378
# 3   273757.0  1.777748e+07   31.327321
# 2   142659.0  1.059216e+07   18.456271
# 11  186892.0  9.796032e+06   17.030168
# 13  146167.0  8.997675e+06   15.600072
# 16  197642.0  8.472486e+06   14.659303
# 22   72245.0  6.698380e+06   11.481350
# 18  179861.0  5.796848e+06    9.866437
# 10  174762.0  4.036187e+06    6.712570
# 7   121323.0  3.279850e+06    5.357745
# 6   184080.0  1.073378e+06    1.405296
# 23   64406.0  9.659340e+05    1.212832
# 20  103100.0  2.888651e+05    0.000000

# %%
# Priority Score 계산
df_gu_summary['PriorityScore'] = (
    0.45 * df_gu_summary['장기미대출비율'] +
    0.30 * (100 - df_gu_summary['장서회전율정규화']) +
    0.25 * (100 - df_gu_summary['미래대출지수정규화'])
)

# 결과 확인 (점수 높은 순 정렬)
priority_result = df_gu_summary[['자치구', '장기미대출비율', '장서회전율정규화', '미래대출지수정규화', 'PriorityScore']].sort_values(by='PriorityScore', ascending=False)

display(priority_result)
# Out:
#      자치구    장기미대출비율    장서회전율정규화   미래대출지수정규화  PriorityScore
# 20   용산구  19.064819    0.000000    0.000000      63.579169
# 10  동대문구  12.550007   18.743368    6.712570      53.346350
# 6    구로구   5.946411   14.592140    1.405296      52.946919
# 23    중구   9.483130   20.240993    1.212832      52.891903
# 7    금천구   9.667855   22.145356    5.357745      51.367492
# 22   종로구   6.539289   27.586961   11.481350      46.796255
# 18   양천구   7.064425   37.544573    9.866437      44.449010
# 16   성북구   7.940267   39.831995   14.659303      42.958696
# 13  서대문구   8.401696   45.579663   15.600072      41.206846
# 9    도봉구   5.547793   41.061406   31.720378      37.247990
# 4    관악구   6.765781   42.075962   35.237361      36.612472
# 2    강북구   3.371677   52.127419   18.456271      36.264961
# 21   은평구   6.602613   48.474509   31.939545      35.443937
# 11   동작구   1.680542   56.120064   17.030168      34.662682
# 15   성동구   3.426865   55.923006   36.064252      30.749124
# 3    강서구   4.751513   64.838206   31.327321      29.854889
# 24   중랑구   5.457590   61.990209   44.366651      27.767190
# 19  영등포구   1.219290   67.161135   33.426981      27.043595
# 1    강동구   3.387875   75.675459   37.638959      24.412166
# 8    노원구   3.770061   59.423226   68.577650      21.725147
# 12   마포구   5.194568   64.199272   74.818500      19.373149
# 0    강남구   2.461329   76.470416   65.991523      16.668593
# 14   서초구   2.190897   85.297011   64.400250      14.296738
# 17   송파구   3.213099   90.161865   69.716129      11.968303
# 5    광진구   4.616990  100.000000  100.000000       2.077645

# %%
display(priority_result.head(10).round(2))
# Out:
#      자치구  장기미대출비율  장서회전율정규화  미래대출지수정규화  PriorityScore
# 20   용산구    19.06      0.00       0.00          63.58
# 10  동대문구    12.55     18.74       6.71          53.35
# 6    구로구     5.95     14.59       1.41          52.95
# 23    중구     9.48     20.24       1.21          52.89
# 7    금천구     9.67     22.15       5.36          51.37
# 22   종로구     6.54     27.59      11.48          46.80
# 18   양천구     7.06     37.54       9.87          44.45
# 16   성북구     7.94     39.83      14.66          42.96
# 13  서대문구     8.40     45.58      15.60          41.21
# 9    도봉구     5.55     41.06      31.72          37.25

# %%
display(priority_result. tail(10).round(2))
# Out:
#      자치구  장기미대출비율  장서회전율정규화  미래대출지수정규화  PriorityScore
# 3    강서구     4.75     64.84      31.33          29.85
# 24   중랑구     5.46     61.99      44.37          27.77
# 19  영등포구     1.22     67.16      33.43          27.04
# 1    강동구     3.39     75.68      37.64          24.41
# 8    노원구     3.77     59.42      68.58          21.73
# 12   마포구     5.19     64.20      74.82          19.37
# 0    강남구     2.46     76.47      65.99          16.67
# 14   서초구     2.19     85.30      64.40          14.30
# 17   송파구     3.21     90.16      69.72          11.97
# 5    광진구     4.62    100.00     100.00           2.08

# %% [markdown]
# ##2. Potential Score: 자치구 별 도서 대출 가능도
#
# y = 0.30×주제장서회전점수+0.20×주제선호도점수+0.20×생활인구점수+0.20×장서부족도점수+0.10×인구증가율점수
#
# * Potential Score는 주제별 수요(장서회전율, 주제선호도)와 지역의 장서 확충 필요성(장서부족도, 생활인구, 인구증가율)을 함께 반영한 종합지표

# %% [markdown]
# ###2-1. 주제 장서회전점수
# Min-Max 정규화[log{1 + (해당 자치구의 해당 KDC 주제 대출건수 ÷ 해당 자치구의 해당 KDC 주제 총소장권수)}] × 100

# %%
import pandas as pd
import numpy as np
import os
import unicodedata

loan_folder = (
    "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_전처리"
)

loan_files = [
    os.path.join(loan_folder, file_name)
    for file_name in os.listdir(loan_folder)
    if file_name.lower().endswith(".csv")
]

if len(loan_files) == 0:
    raise ValueError("장서대출 CSV 파일을 찾지 못했습니다.")

kdc_map = {
    "0": "총류",
    "1": "철학",
    "2": "종교",
    "3": "사회과학",
    "4": "자연과학",
    "5": "기술과학",
    "6": "예술",
    "7": "언어",
    "8": "문학",
    "9": "역사"
}

topic_order = [
    "총류",
    "철학",
    "종교",
    "사회과학",
    "자연과학",
    "기술과학",
    "예술",
    "언어",
    "문학",
    "역사"
]

def extract_district(file_path):
    file_name = os.path.basename(file_path)
    file_name = unicodedata.normalize("NFC", file_name)
    file_name = os.path.splitext(file_name)[0]
    parts = file_name.split("_")

    if len(parts) >= 3:
        return parts[1].strip()

    return None

def read_csv_auto(file_path):
    encodings = ["utf-8-sig", "utf-8", "cp949", "euc-kr"]

    for encoding in encodings:
        try:
            return pd.read_csv(
                file_path,
                encoding=encoding,
                low_memory=False
            )
        except UnicodeDecodeError:
            continue

    raise ValueError(f"파일을 읽을 수 없습니다: {file_path}")

topic_summary_list = []
classification_check_list = []
file_error_list = []

for file_path in loan_files:

    district = extract_district(file_path)

    if district is None:
        file_error_list.append({
            "파일명": os.path.basename(file_path),
            "오류": "자치구명 추출 실패"
        })
        continue

    try:
        df = read_csv_auto(file_path)
    except Exception as error:
        file_error_list.append({
            "파일명": os.path.basename(file_path),
            "오류": str(error)
        })
        continue

    df.columns = df.columns.astype(str).str.strip()

    required_columns = [
        "주제분류번호",
        "도서권수",
        "대출건수"
    ]

    missing_columns = [
        column
        for column in required_columns
        if column not in df.columns
    ]

    if missing_columns:
        file_error_list.append({
            "파일명": os.path.basename(file_path),
            "오류": f"필수 열 누락: {missing_columns}"
        })
        continue

    df["도서권수"] = pd.to_numeric(
        df["도서권수"],
        errors="coerce"
    ).fillna(0)

    df["대출건수"] = pd.to_numeric(
        df["대출건수"],
        errors="coerce"
    ).fillna(0)

    df.loc[df["도서권수"] < 0, "도서권수"] = 0
    df.loc[df["대출건수"] < 0, "대출건수"] = 0

    df["주제분류번호_원본"] = (
        df["주제분류번호"]
        .astype("string")
        .fillna("")
        .str.strip()
    )

    df["KDC번호_추출"] = (
        df["주제분류번호_원본"]
        .str.extract(
            r"([0-9]{3}(?:\.[0-9]+)?)",
            expand=False
        )
    )

    df["KDC앞자리"] = df["KDC번호_추출"].str[0]
    df["KDC주제"] = df["KDC앞자리"].map(kdc_map)

    valid_df = df[df["KDC주제"].notna()].copy()
    invalid_df = df[df["KDC주제"].isna()].copy()

    total_rows = len(df)
    total_books = df["도서권수"].sum()
    total_loans = df["대출건수"].sum()

    invalid_rows = len(invalid_df)
    invalid_books = invalid_df["도서권수"].sum()
    invalid_loans = invalid_df["대출건수"].sum()

    classification_check_list.append({
        "자치구": district,
        "전체행수": total_rows,
        "분류가능행수": len(valid_df),
        "미분류행수": invalid_rows,
        "전체도서권수": total_books,
        "미분류도서권수": invalid_books,
        "전체대출건수": total_loans,
        "미분류대출건수": invalid_loans,
        "행기준_미분류비율(%)": (
            invalid_rows / total_rows * 100
            if total_rows > 0
            else np.nan
        ),
        "도서권수기준_미분류비율(%)": (
            invalid_books / total_books * 100
            if total_books > 0
            else np.nan
        ),
        "대출건수기준_미분류비율(%)": (
            invalid_loans / total_loans * 100
            if total_loans > 0
            else np.nan
        )
    })

    grouped = (
        valid_df
        .groupby(
            "KDC주제",
            as_index=False,
            observed=False
        )
        .agg(
            주제별_도서권수=("도서권수", "sum"),
            주제별_대출건수=("대출건수", "sum")
        )
    )

    grouped["자치구"] = district
    topic_summary_list.append(grouped)

if len(topic_summary_list) == 0:
    raise ValueError("정상적으로 처리된 파일이 없습니다.")

topic_turnover = pd.concat(
    topic_summary_list,
    ignore_index=True
)

districts = sorted(
    topic_turnover["자치구"]
    .dropna()
    .unique()
)

full_index = pd.MultiIndex.from_product(
    [districts, topic_order],
    names=["자치구", "KDC주제"]
)

topic_turnover = (
    topic_turnover
    .set_index(["자치구", "KDC주제"])
    .reindex(full_index)
    .reset_index()
)

topic_turnover[
    ["주제별_도서권수", "주제별_대출건수"]
] = (
    topic_turnover[
        ["주제별_도서권수", "주제별_대출건수"]
    ]
    .fillna(0)
)

# %%
topic_turnover["주제별_장서회전율"] = np.where(
    topic_turnover["주제별_도서권수"] > 0,
    topic_turnover["주제별_대출건수"]
    / topic_turnover["주제별_도서권수"],
    np.nan
)

topic_turnover["로그_주제별_장서회전율"] = np.log1p(
    topic_turnover["주제별_장서회전율"]
)

def minmax_by_topic(series):
    valid_series = series.dropna()

    if len(valid_series) == 0:
        return pd.Series(
            np.nan,
            index=series.index
        )

    min_value = valid_series.min()
    max_value = valid_series.max()

    if max_value == min_value:
        return pd.Series(
            np.where(
                series.notna(),
                50.0,
                np.nan
            ),
            index=series.index
        )

    return (
        (series - min_value)
        / (max_value - min_value)
        * 100
    )

topic_turnover["주제별_장서회전점수"] = (
    topic_turnover
    .groupby(
        "KDC주제",
        observed=False
    )["로그_주제별_장서회전율"]
    .transform(minmax_by_topic)
)

topic_turnover["KDC주제"] = pd.Categorical(
    topic_turnover["KDC주제"],
    categories=topic_order,
    ordered=True
)

topic_turnover = (
    topic_turnover
    .sort_values(["자치구", "KDC주제"])
    .reset_index(drop=True)
)

topic_turnover[
    [
        "주제별_장서회전율",
        "로그_주제별_장서회전율",
        "주제별_장서회전점수"
    ]
] = (
    topic_turnover[
        [
            "주제별_장서회전율",
            "로그_주제별_장서회전율",
            "주제별_장서회전점수"
        ]
    ]
    .round(4)
)

classification_check = pd.DataFrame(
    classification_check_list
)

classification_check = (
    classification_check
    .sort_values(
        "대출건수기준_미분류비율(%)",
        ascending=False
    )
    .reset_index(drop=True)
)

percentage_columns = [
    "행기준_미분류비율(%)",
    "도서권수기준_미분류비율(%)",
    "대출건수기준_미분류비율(%)"
]

classification_check[percentage_columns] = (
    classification_check[percentage_columns]
    .round(2)
)

file_error_result = pd.DataFrame(file_error_list)

display(topic_turnover)
display(classification_check)
display(file_error_result)
# Out:
#      자치구 KDC주제  주제별_도서권수  주제별_대출건수  주제별_장서회전율  로그_주제별_장서회전율  주제별_장서회전점수
# 0    강남구    총류     23621    486334    20.5891        3.0722     71.1329
# 1    강남구    철학     31556    637627    20.2062        3.0543     81.8258
# 2    강남구    종교     13033    362135    27.7860        3.3599     90.2302
# 3    강남구  사회과학    103041   2318857    22.5042        3.1572     86.9730
# 4    강남구  자연과학     80507   3154114    39.1781        3.6933     89.0715
# ..   ...   ...       ...       ...        ...           ...         ...
# 245  중랑구  기술과학     51808    916463    17.6896        2.9280     80.5526
# 246  중랑구    예술     25212    418955    16.6173        2.8689     68.2942
# 247  중랑구    언어     28527    717550    25.1534        3.2640     65.6248
# 248  중랑구    문학    440424  13580890    30.8359        3.4606     82.0411
# 249  중랑구    역사     66541   1656820    24.8992        3.2542     71.5452
#
# [250 rows x 7 columns]
#      자치구     전체행수   분류가능행수   미분류행수   전체도서권수  미분류도서권수    전체대출건수  미분류대출건수  \
# 0    강북구   700572   548142  152430   737455   155130  15035683  1486809
# 1    성북구   435044   386272   48772   453971    49031   8210268   526773
# 2    도봉구  1185370  1064958  120412  1323927   122627  24385338  1074870
# 3    종로구  1014531   917162   97369  1243835    99048  17441215   626880
# 4    중랑구   835702   808237   27465   912753    32005  24092029   695218
# 5    광진구  1261986  1247244   14742  1481863    18372  59262059  1434795
# 6    금천구   377959   364165   13794   385065    14367   4899471   104084
# 7    용산구    99122    96403    2719   101242     2814    508333     8419
# 8    서초구   997481   977339   20142  1080527    20698  37499534   544189
# 9    강동구   520609   506487   14122   537387    14327  16805158   237255
# 10   동작구   376796   368583    8213   386409     8266   9515164   126368
# 11   양천구   320862   312376    8486   327999     8515   5870631    66975
# 12   송파구   669838   657354   12484   681193    12519  24851628   283402
# 13   성동구  1068786  1052769   16017  1122146    16995  27583200   304260
# 14   노원구  1222666  1207239   15427  1255952    15832  32422066   298836
# 15   관악구   619133   612496    6637   633412     7110  12485571    91799
# 16   마포구  1408209  1397078   11131  1540875    11500  42349644   218361
# 17    중구   227028   225998    1030   227565     1039   2757138    12368
# 18  동대문구   317866   311084    6782   357093     6891   4071919    12512
# 19   강남구   788522   785352    3170   857169     3410  27256878    43424
# 20  영등포구   616032   613916    2116   625948     2142  17819075    16968
# 21   은평구   635639   629653    5986   703633     5988  15356399     7962
# 22   구로구   100520   100495      25   104525       25   1059480       20
# 23  서대문구   514802   514590     212   531939      215  11159229       59
# 24   강서구   416610   416610       0   425696        0  11804138        0
#
#     행기준_미분류비율(%)  도서권수기준_미분류비율(%)  대출건수기준_미분류비율(%)
# 0          21.76            21.04             9.89
# 1          11.21            10.80             6.42
# 2          10.16             9.26             4.41
# 3           9.60             7.96             3.59
# 4           3.29             3.51             2.89
# 5           1.17             1.24             2.42
# 6           3.65             3.73             2.12
# 7           2.74             2.78             1.66
# 8           2.02             1.92             1.45
# 9           2.71             2.67             1.41
# 10          2.18             2.14             1.33
# 11          2.64             2.60             1.14
# 12          1.86             1.84             1.14
# 13          1.50             1.51             1.10
# 14          1.26             1.26             0.92
# 15          1.07             1.12             0.74
# 16          0.79             0.75             0.52
# 17          0.45             0.46             0.45
# 18          2.13             1.93             0.31
# 19          0.40             0.40             0.16
# 20          0.34             0.34             0.10
# 21          0.94             0.85             0.05
# 22          0.02             0.02             0.00
# 23          0.04             0.04             0.00
# 24          0.00             0.00             0.00
# Empty DataFrame
# Columns: []
# Index: []

# %%
output_path = (
    "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/주제별_장서회전점수.csv"
)

topic_turnover.to_csv(
    output_path,
    index=False,
    encoding="utf-8-sig"
)

print("저장 완료:", output_path)
# Out:
# 저장 완료: /content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/주제별_장서회전점수.csv

# %% [markdown]
# ### 2-2. 주제선호도점수
# 해당 자치구의 해당 KDC 주제 대출건수 / 해당 자치구의 전체 도서 대출건수 × 100

# %%
import pandas as pd

df = pd.read_csv(
    "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/주제수요점수.csv",
    encoding="utf-8-sig"
)

display(df)
# Out:
#      자치구    총류    철학    종교   사회과학   자연과학  기술과학    예술     언어     문학    역사  \
# 0    강남구  1.78  2.35  1.34   8.54  11.59  4.27  3.83   6.83  51.37  8.08
# 1    강동구  0.31  2.70  1.65   9.32   8.34  3.92  2.65  14.04  49.38  7.67
# 2    강북구  2.14  4.13  1.47   9.62   7.36  3.91  2.51   8.69  42.56  7.82
# 3    강서구  2.35  4.06  1.58  12.34   6.65  3.70  1.99   2.65  55.72  8.97
# 4    관악구  3.39  5.19  2.10  13.04   6.25  4.86  3.22   5.68  49.03  7.22
# 5    구로구  2.32  4.21  2.08  11.95   7.60  5.25  1.94   5.02  52.57  7.05
# 6    금천구  0.00  4.17  2.35  14.02  10.55  5.66  2.92   7.53  44.60  8.17
# 7    노원구  1.71  4.04  1.77  12.71   7.36  5.45  3.35   5.23  51.97  6.42
# 8    도봉구  2.26  4.39  1.73  11.35   7.43  5.42  2.94   4.12  49.67  7.22
# 9   동대문구  4.63  5.15  2.30  16.39   5.92  6.54  4.31   5.33  40.98  8.13
# 10   동작구  0.00  3.85  2.07  10.36   7.53  4.43  1.81   3.72  58.82  7.40
# 11   마포구  2.67  3.71  1.29  10.88   9.31  4.80  4.56   4.07  50.79  7.71
# 12  서대문구  1.91  2.03  1.15  11.27   7.59  3.45  2.46   3.26  59.37  7.51
# 13   서초구  1.70  2.67  0.82   8.36   7.67  3.55  1.97   4.65  61.48  6.54
# 14   성동구  1.47  3.13  3.65   9.60   8.30  3.61  2.54   9.87  50.42  7.42
# 15   성북구  1.94  3.95  1.76  11.44   6.88  3.75  2.17   5.29  50.15  6.25
# 16   송파구  0.54  2.01  1.07   8.64  12.45  3.72  6.28  11.70  44.57  9.01
# 17   양천구  0.95  2.89  1.99  10.36  10.69  4.78  2.07   6.16  53.72  6.40
# 18  영등포구  1.89  3.10  0.85  10.97   8.65  3.58  1.61   6.40  55.51  7.44
# 19   용산구  0.00  5.71  0.89  14.95   5.98  4.87  1.79   2.70  54.52  8.59
# 20   은평구  2.53  3.75  1.90  11.57  10.03  3.99  2.65   8.47  48.07  6.98
# 21   종로구  3.08  5.43  2.01  12.98   6.53  5.63  5.40   4.47  43.26  7.61
# 22    중구  1.46  3.46  1.25  11.76   7.50  5.21  2.43   6.95  52.59  7.39
# 23   중랑구  0.76  3.71  0.97  12.78   7.76  4.00  1.74   2.98  57.90  6.88
# 24   광진구  3.68  2.98  2.08   9.86  10.57  3.62  4.57   5.83  48.16  8.64
#
#      미분류      합계
# 0   0.00   99.98
# 1   0.00   99.98
# 2   9.80  100.01
# 3   0.00  100.01
# 4   0.01   99.99
# 5   0.00   99.99
# 6   0.04  100.01
# 7   0.00  100.01
# 8   3.47  100.00
# 9   0.31   99.99
# 10  0.00   99.99
# 11  0.21  100.00
# 12  0.00  100.00
# 13  0.58   99.99
# 14  0.00  100.01
# 15  6.42  100.00
# 16  0.01  100.00
# 17  0.00  100.01
# 18  0.00  100.00
# 19  0.01  100.01
# 20  0.05   99.99
# 21  3.59   99.99
# 22  0.00  100.00
# 23  0.52  100.00
# 24  0.00   99.99

# %%
#주제선호도점수
preference_rate = df.copy()

topic_columns = [
    "총류",
    "철학",
    "종교",
    "사회과학",
    "자연과학",
    "기술과학",
    "예술",
    "언어",
    "문학",
    "역사"
]

preference_score = df[["자치구"]].copy()

for column in topic_columns:
    min_value = df[column].min()
    max_value = df[column].max()

    if max_value == min_value:
        preference_score[f"{column}_선호도점수"] = 50.0
    else:
        preference_score[f"{column}_선호도점수"] = (
            (df[column] - min_value)
            / (max_value - min_value)
            * 100
        )

score_columns = [
    column
    for column in preference_score.columns
    if column != "자치구"
]

preference_score[score_columns] = (
    preference_score[score_columns]
    .round(4)
)

display(preference_score)
# Out:
#      자치구  총류_선호도점수  철학_선호도점수  종교_선호도점수  사회과학_선호도점수  자연과학_선호도점수  기술과학_선호도점수  \
# 0    강남구   38.4449    9.1892   18.3746      2.2416     86.8300     26.5372
# 1    강동구    6.6955   18.6486   29.3286     11.9552     37.0597     15.2104
# 2    강북구   46.2203   57.2973   22.9682     15.6912     22.0521     14.8867
# 3    강서구   50.7559   55.4054   26.8551     49.5641     11.1792      8.0906
# 4    관악구   73.2181   85.9459   45.2297     58.2814      5.0536     45.6311
# 5    구로구   50.1080   59.4595   44.5230     44.7073     25.7274     58.2524
# 6    금천구    0.0000   58.3784   54.0636     70.4857     70.9035     71.5210
# 7    노원구   36.9330   54.8649   33.5689     54.1719     22.0521     64.7249
# 8    도봉구   48.8121   64.3243   32.1555     37.2354     23.1240     63.7540
# 9   동대문구  100.0000   84.8649   52.2968    100.0000      0.0000    100.0000
# 10   동작구    0.0000   49.7297   44.1696     24.9066     24.6554     31.7152
# 11   마포구   57.6674   45.9459   16.6078     31.3823     51.9142     43.6893
# 12  서대문구   41.2527    0.5405   11.6608     36.2391     25.5743      0.0000
# 13   서초구   36.7171   17.8378    0.0000      0.0000     26.7994      3.2362
# 14   성동구   31.7495   30.2703  100.0000     15.4421     36.4472      5.1780
# 15   성북구   41.9006   52.4324   33.2155     38.3562     14.7014      9.7087
# 16   송파구   11.6631    0.0000    8.8339      3.4869    100.0000      8.7379
# 17   양천구   20.5184   23.7838   41.3428     24.9066     73.0475     43.0421
# 18  영등포구   40.8207   29.4595    1.0601     32.5031     41.8070      4.2071
# 19   용산구    0.0000  100.0000    2.4735     82.0672      0.9188     45.9547
# 20   은평구   54.6436   47.0270   38.1625     39.9751     62.9403     17.4757
# 21   종로구   66.5227   92.4324   42.0495     57.5342      9.3415     70.5502
# 22    중구   31.5335   39.1892   15.1943     42.3412     24.1960     56.9579
# 23   중랑구   16.4147   45.9459    5.3004     55.0436     28.1776     17.7994
# 24   광진구   79.4816   26.2162   44.5230     18.6800     71.2098      5.5016
#
#     예술_선호도점수  언어_선호도점수  문학_선호도점수  역사_선호도점수
# 0    47.5375   36.6989   50.6829   66.3043
# 1    22.2698  100.0000   40.9756   51.4493
# 2    19.2719   53.0290    7.7073   56.8841
# 3     8.1370    0.0000   71.9024   98.5507
# 4    34.4754   26.6023   39.2683   35.1449
# 5     7.0664   20.8077   56.5366   28.9855
# 6    28.0514   42.8446   17.6585   69.5652
# 7    37.2591   22.6514   53.6098    6.1594
# 8    28.4797   12.9061   42.3902   35.1449
# 9    57.8158   23.5294    0.0000   68.1159
# 10    4.2827    9.3942   87.0244   41.6667
# 11   63.1692   12.4671   47.8537   52.8986
# 12   18.2013    5.3556   89.7073   45.6522
# 13    7.7088   17.5593  100.0000   10.5072
# 14   19.9143   63.3889   46.0488   42.3913
# 15   11.9914   23.1782   44.7317    0.0000
# 16  100.0000   79.4557   17.5122  100.0000
# 17    9.8501   30.8165   62.1463    5.4348
# 18    0.0000   32.9236   70.8780   43.1159
# 19    3.8544    0.4390   66.0488   84.7826
# 20   22.2698   51.0975   34.5854   26.4493
# 21   81.1563   15.9789   11.1220   49.2754
# 22   17.5589   37.7524   56.6341   41.3043
# 23    2.7837    2.8973   82.5366   22.8261
# 24   63.3833   27.9192   35.0244   86.5942

# %%
preference_long = preference_score.melt(
    id_vars="자치구",
    var_name="KDC주제",
    value_name="주제선호도점수"
)

preference_long["KDC주제"] = (
    preference_long["KDC주제"]
    .str.replace("_선호도점수", "", regex=False)
)

preference_long = (
    preference_long
    .sort_values(["자치구", "KDC주제"])
    .reset_index(drop=True)
)

display(preference_long)
# Out:
#      자치구 KDC주제  주제선호도점수
# 0    강남구  기술과학  26.5372
# 1    강남구    문학  50.6829
# 2    강남구  사회과학   2.2416
# 3    강남구    언어  36.6989
# 4    강남구    역사  66.3043
# ..   ...   ...      ...
# 245  중랑구    예술   2.7837
# 246  중랑구  자연과학  28.1776
# 247  중랑구    종교   5.3004
# 248  중랑구    철학  45.9459
# 249  중랑구    총류  16.4147
#
# [250 rows x 3 columns]

# %%
output_path = (
    "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/주제별_선호도점수.csv"
)

preference_long.to_csv(
    output_path,
    index=False,
    encoding="utf-8-sig"
)

print("저장 완료:", output_path)
# Out:
# 저장 완료: /content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/주제별_선호도점수.csv

# %% [markdown]
# ### 2-3. 생활인구점수
# (해당 자치구 평균 생활 인구 - 자치구 중 최소 값)/(자치구 중 최대 값 - 자치구 중 최소값) × 100

# %%
import pandas as pd
import glob
import os
import re

# %%
from pathlib import Path

input_folder = Path(
    "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/행정구역별 생활인구"
)

output_folder = input_folder / "자치구_매핑완료"
output_folder.mkdir(exist_ok=True)

file_list = sorted(
    input_folder.glob("LOCAL_PEOPLE_DONG_*_age10.csv")
)

print("폴더 존재:", input_folder.exists())
print("찾은 파일 수:", len(file_list))

for file in file_list[:10]:
    print(file.name)
# Out:
# 폴더 존재: True
# 찾은 파일 수: 36
# LOCAL_PEOPLE_DONG_202306_age10.csv
# LOCAL_PEOPLE_DONG_202307_age10.csv
# LOCAL_PEOPLE_DONG_202308_age10.csv
# LOCAL_PEOPLE_DONG_202309_age10.csv
# LOCAL_PEOPLE_DONG_202310_age10.csv
# LOCAL_PEOPLE_DONG_202311_age10.csv
# LOCAL_PEOPLE_DONG_202312_age10.csv
# LOCAL_PEOPLE_DONG_202401_age10.csv
# LOCAL_PEOPLE_DONG_202402_age10.csv
# LOCAL_PEOPLE_DONG_202403_age10.csv

# %%
#행정동별 자치구 매핑
gu_map = {
    "11110": "종로구",
    "11140": "중구",
    "11170": "용산구",
    "11200": "성동구",
    "11215": "광진구",
    "11230": "동대문구",
    "11260": "중랑구",
    "11290": "성북구",
    "11305": "강북구",
    "11320": "도봉구",
    "11350": "노원구",
    "11380": "은평구",
    "11410": "서대문구",
    "11440": "마포구",
    "11470": "양천구",
    "11500": "강서구",
    "11530": "구로구",
    "11545": "금천구",
    "11560": "영등포구",
    "11590": "동작구",
    "11620": "관악구",
    "11650": "서초구",
    "11680": "강남구",
    "11710": "송파구",
    "11740": "강동구"
}

all_data = []

print("="*60)

for file_path in file_list:

    file_name = file_path.name

    print(f"\n처리 중 : {file_name}")


    df = pd.read_csv(
        file_path,
        encoding="utf-8-sig"
    )


    df["행정동코드"] = (
        df["행정동코드"]
        .astype(str)
        .str.replace(".0", "", regex=False)
        .str.zfill(8)
    )


    df["자치구코드"] = df["행정동코드"].str[:5]

    df["자치구명"] = df["자치구코드"].map(gu_map)


    year_month = re.search(
        r"(\d{6})",
        file_name
    ).group()

    df["기준연월"] = year_month


    save_name = file_name.replace(
        ".csv",
        "_자치구매핑.csv"
    )

    save_path = output_folder / save_name

    df.to_csv(
        save_path,
        index=False,
        encoding="utf-8-sig"
    )

    all_data.append(df)

    print(
        "완료 |",
        year_month,
        "|",
        len(df),
        "행"
    )

print("\n")
print("="*60)
print("모든 파일 처리 완료")
print("총 파일 수 :", len(all_data))
# Out:
# ============================================================
#
# 처리 중 : LOCAL_PEOPLE_DONG_202306_age10.csv
# 완료 | 202306 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202307_age10.csv
# 완료 | 202307 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202308_age10.csv
# 완료 | 202308 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202309_age10.csv
# 완료 | 202309 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202310_age10.csv
# 완료 | 202310 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202311_age10.csv
# 완료 | 202311 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202312_age10.csv
# 완료 | 202312 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202401_age10.csv
# 완료 | 202401 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202402_age10.csv
# 완료 | 202402 | 295104 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202403_age10.csv
# 완료 | 202403 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202404_age10.csv
# 완료 | 202404 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202405_age10.csv
# 완료 | 202405 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202406_age10.csv
# 완료 | 202406 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202407_age10.csv
# 완료 | 202407 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202408_age10.csv
# 완료 | 202408 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202409_age10.csv
# 완료 | 202409 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202410_age10.csv
# 완료 | 202410 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202411_age10.csv
# 완료 | 202411 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202412_age10.csv
# 완료 | 202412 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202501_age10.csv
# 완료 | 202501 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202502_age10.csv
# 완료 | 202502 | 284928 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202503_age10.csv
# 완료 | 202503 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202504_age10.csv
# 완료 | 202504 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202505_age10.csv
# 완료 | 202505 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202506_age10.csv
# 완료 | 202506 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202507_age10.csv
# 완료 | 202507 | 295104 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202508_age10.csv
# 완료 | 202508 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202509_age10.csv
# 완료 | 202509 | 305204 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202510_age10.csv
# 완료 | 202510 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202511_age10.csv
# 완료 | 202511 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202512_age10.csv
# 완료 | 202512 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202601_age10.csv
# 완료 | 202601 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202602_age10.csv
# 완료 | 202602 | 284928 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202603_age10.csv
# 완료 | 202603 | 315456 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202604_age10.csv
# 완료 | 202604 | 305280 행
#
# 처리 중 : LOCAL_PEOPLE_DONG_202605_age10.csv
# 완료 | 202605 | 315456 행
#
#
# ============================================================
# 모든 파일 처리 완료
# 총 파일 수 : 36

# %%
import pandas as pd
import re
from pathlib import Path

input_folder = Path(
    "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/"
    "행정구역별 생활인구/자치구_매핑완료"
)

output_folder = input_folder / "생활인구점수_산출결과"
output_folder.mkdir(parents=True, exist_ok=True)

# %%
file_list = sorted([
    item
    for item in input_folder.iterdir()
    if item.is_file() and item.suffix.lower() == ".csv"
])

print("찾은 파일 수:", len(file_list))

for file_path in file_list[:10]:
    print(file_path.name)
# Out:
# 찾은 파일 수: 36
# LOCAL_PEOPLE_DONG_202306_age10_자치구매핑.csv
# LOCAL_PEOPLE_DONG_202307_age10_자치구매핑.csv
# LOCAL_PEOPLE_DONG_202308_age10_자치구매핑.csv
# LOCAL_PEOPLE_DONG_202309_age10_자치구매핑.csv
# LOCAL_PEOPLE_DONG_202310_age10_자치구매핑.csv
# LOCAL_PEOPLE_DONG_202311_age10_자치구매핑.csv
# LOCAL_PEOPLE_DONG_202312_age10_자치구매핑.csv
# LOCAL_PEOPLE_DONG_202401_age10_자치구매핑.csv
# LOCAL_PEOPLE_DONG_202402_age10_자치구매핑.csv
# LOCAL_PEOPLE_DONG_202403_age10_자치구매핑.csv

# %%
import pandas as pd
import re

monthly_results = []
error_files = []

for file_path in file_list:

    file_name = file_path.name
    print(f"\n처리 중: {file_name}")

    try:
        df = pd.read_csv(
            file_path,
            encoding="utf-8-sig",
            dtype={
                "행정동코드": str,
                "자치구코드": str,
                "자치구명": str,
                "기준연월": str
            }
        )

        df["시간대구분"] = pd.to_numeric(
            df["시간대구분"],
            errors="coerce"
        )

        df["총생활인구수"] = pd.to_numeric(
            df["총생활인구수"],
            errors="coerce"
        )

        df = df.dropna(
            subset=[
                "기준일ID",
                "시간대구분",
                "총생활인구수",
                "자치구명"
            ]
        ).copy()

        # 도서관 이용 가능 시간대: 09시~19시
        df_time = df[
            df["시간대구분"].between(9, 19)
        ].copy()

        # 날짜·시간대·자치구별 행정동 생활인구 합산
        gu_hourly = (
            df_time
            .groupby(
                ["기준일ID", "시간대구분", "자치구명"],
                as_index=False
            )["총생활인구수"]
            .sum()
            .rename(
                columns={
                    "총생활인구수": "자치구_시간대생활인구"
                }
            )
        )

        # 날짜별 자치구 평균생활인구
        gu_daily = (
            gu_hourly
            .groupby(
                ["기준일ID", "자치구명"],
                as_index=False
            )["자치구_시간대생활인구"]
            .mean()
            .rename(
                columns={
                    "자치구_시간대생활인구": "일평균생활인구"
                }
            )
        )

        year_month = re.search(
            r"(\d{6})",
            file_name
        ).group(1)

        # 월별 자치구 평균생활인구
        gu_monthly = (
            gu_daily
            .groupby(
                "자치구명",
                as_index=False
            )["일평균생활인구"]
            .mean()
            .rename(
                columns={
                    "일평균생활인구": "월평균생활인구"
                }
            )
        )

        gu_monthly["기준연월"] = year_month

        gu_monthly = gu_monthly[
            ["기준연월", "자치구명", "월평균생활인구"]
        ]

        monthly_results.append(gu_monthly)

        print(
            f"완료: {year_month} | "
            f"자치구 수: {gu_monthly['자치구명'].nunique()}"
        )

    except Exception as e:
        error_files.append({
            "파일명": file_name,
            "오류내용": str(e)
        })

        print("오류:", e)
# Out:
# 처리 중: LOCAL_PEOPLE_DONG_202306_age10_자치구매핑.csv
# 완료: 202306 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202307_age10_자치구매핑.csv
# 완료: 202307 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202308_age10_자치구매핑.csv
# 완료: 202308 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202309_age10_자치구매핑.csv
# 완료: 202309 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202310_age10_자치구매핑.csv
# 완료: 202310 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202311_age10_자치구매핑.csv
# 완료: 202311 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202312_age10_자치구매핑.csv
# 완료: 202312 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202401_age10_자치구매핑.csv
# 완료: 202401 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202402_age10_자치구매핑.csv
# 완료: 202402 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202403_age10_자치구매핑.csv
# 완료: 202403 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202404_age10_자치구매핑.csv
# 완료: 202404 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202405_age10_자치구매핑.csv
# 완료: 202405 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202406_age10_자치구매핑.csv
# 완료: 202406 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202407_age10_자치구매핑.csv
# 완료: 202407 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202408_age10_자치구매핑.csv
# 완료: 202408 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202409_age10_자치구매핑.csv
# 완료: 202409 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202410_age10_자치구매핑.csv
# 완료: 202410 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202411_age10_자치구매핑.csv
# 완료: 202411 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202412_age10_자치구매핑.csv
# 완료: 202412 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202501_age10_자치구매핑.csv
# 완료: 202501 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202502_age10_자치구매핑.csv
# 완료: 202502 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202503_age10_자치구매핑.csv
# 완료: 202503 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202504_age10_자치구매핑.csv
# 완료: 202504 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202505_age10_자치구매핑.csv
# 완료: 202505 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202506_age10_자치구매핑.csv
# 완료: 202506 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202507_age10_자치구매핑.csv
# 완료: 202507 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202508_age10_자치구매핑.csv
# 완료: 202508 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202509_age10_자치구매핑.csv
# 완료: 202509 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202510_age10_자치구매핑.csv
# 완료: 202510 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202511_age10_자치구매핑.csv
# 완료: 202511 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202512_age10_자치구매핑.csv
# 완료: 202512 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202601_age10_자치구매핑.csv
# 완료: 202601 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202602_age10_자치구매핑.csv
# 완료: 202602 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202603_age10_자치구매핑.csv
# 완료: 202603 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202604_age10_자치구매핑.csv
# 완료: 202604 | 자치구 수: 25
#
# 처리 중: LOCAL_PEOPLE_DONG_202605_age10_자치구매핑.csv
# 완료: 202605 | 자치구 수: 25

# %%
if len(monthly_results) == 0:
    raise ValueError("정상 처리된 월별 결과가 없습니다.")

monthly_all = pd.concat(
    monthly_results,
    ignore_index=True
)

monthly_all = monthly_all.sort_values(
    ["기준연월", "자치구명"]
).reset_index(drop=True)

monthly_all_path = (
    output_folder
    / "202306_202605_자치구별_월평균생활인구.csv"
)

monthly_all.to_csv(
    monthly_all_path,
    index=False,
    encoding="utf-8-sig"
)

print("전체 행 수:", len(monthly_all))
print("연월 수:", monthly_all["기준연월"].nunique())
print("자치구 수:", monthly_all["자치구명"].nunique())
print("저장 위치:", monthly_all_path)
# Out:
# 전체 행 수: 900
# 연월 수: 36
# 자치구 수: 25
# 저장 위치: /content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/행정구역별 생활인구/자치구_매핑완료/생활인구점수_산출결과/202306_202605_자치구별_월평균생활인구.csv

# %%
#자치구별 36개월 평균 계산
gu_36month = (
    monthly_all
    .groupby(
        "자치구명",
        as_index=False
    )["월평균생활인구"]
    .mean()
    .rename(
        columns={
            "월평균생활인구": "36개월평균생활인구"
        }
    )
)

print(gu_36month.head())
print("자치구 수:", gu_36month["자치구명"].nunique())
# Out:
#   자치구명     36개월평균생활인구
# 0  강남구  950727.708540
# 1  강동구  481511.575842
# 2  강북구  248587.568729
# 3  강서구  521648.293373
# 4  관악구  414268.739498
# 자치구 수: 25

# %%
#생활인구점수 계산
min_value = gu_36month["36개월평균생활인구"].min()
max_value = gu_36month["36개월평균생활인구"].max()

if max_value == min_value:
    raise ValueError("모든 자치구 값이 동일하여 정규화 불가")

gu_36month["생활인구점수"] = (
    (
        gu_36month["36개월평균생활인구"] - min_value
    )
    /
    (
        max_value - min_value
    )
    * 100
)

gu_36month["36개월평균생활인구"] = (
    gu_36month["36개월평균생활인구"].round(2)
)

gu_36month["생활인구점수"] = (
    gu_36month["생활인구점수"].round(2)
)

gu_36month = gu_36month.sort_values(
    "생활인구점수",
    ascending=False
).reset_index(drop=True)

gu_36month.insert(
    0,
    "생활인구순위",
    range(1, len(gu_36month) + 1)
)

gu_36month
# Out:
#     생활인구순위  자치구명  36개월평균생활인구  생활인구점수
# 0        1   강남구   950727.71  100.00
# 1        2   송파구   738996.80   70.87
# 2        3   서초구   643045.66   57.67
# 3        4   강서구   521648.29   40.96
# 4        5  영등포구   520322.75   40.78
# 5        6   강동구   481511.58   35.44
# 6        7   마포구   462075.83   32.77
# 7        8   노원구   441793.69   29.98
# 8        9   관악구   414268.74   26.19
# 9       10   성북구   389625.57   22.80
# 10      11   은평구   379635.31   21.42
# 11      12   구로구   375540.51   20.86
# 12      13  서대문구   365921.56   19.54
# 13      14   성동구   350078.67   17.36
# 14      15    중구   346822.90   16.91
# 15      16   광진구   344313.80   16.56
# 16      17   동작구   344077.32   16.53
# 17      18   종로구   341424.80   16.17
# 18      19   양천구   340265.31   16.01
# 19      20  동대문구   337531.76   15.63
# 20      21   중랑구   307517.34   11.50
# 21      22   용산구   297295.87   10.09
# 22      23   강북구   248587.57    3.39
# 23      24   도봉구   239347.87    2.12
# 24      25   금천구   223934.65    0.00

# %%
final_output_path = (
    output_folder
    / "자치구별_36개월평균_생활인구점수.csv"
)

gu_36month.to_csv(
    final_output_path,
    index=False,
    encoding="utf-8-sig"
)

print("최종 저장 완료")
print(final_output_path)
# Out:
# 최종 저장 완료
# /content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/행정구역별 생활인구/자치구_매핑완료/생활인구점수_산출결과/자치구별_36개월평균_생활인구점수.csv

# %% [markdown]
# ### 2-4. 장서부족도점수

# %%
# 인당 장서수
df_analysis["인당장서수"] = (
    df_analysis["총장서수"] / df_analysis["인구수"]
)

# 인당 장서수 Min-Max 정규화 (0~100)
min_book = df_analysis["인당장서수"].min()
max_book = df_analysis["인당장서수"].max()

df_analysis["인당장서수점수"] = (
    (df_analysis["인당장서수"] - min_book)
    / (max_book - min_book)
) * 100

# 장서부족도 점수
df_analysis["장서부족도점수"] = (
    100 - df_analysis["인당장서수점수"]
)

# 결과
df_analysis[[
    "자치구",
    "총장서수",
    "인구수",
    "인당장서수",
    "인당장서수점수",
    "장서부족도점수"
]].sort_values("장서부족도점수", ascending=False)
# Out:
#      자치구      총장서수           인구수     인당장서수     인당장서수점수     장서부족도점수
# 17   송파구  110754.0  1.758906e+07  0.006297    0.000000  100.000000
# 0    강남구  121790.0  1.910052e+07  0.006376    0.228600   99.771400
# 22   종로구   44784.0  6.794531e+06  0.006591    0.846505   99.153495
# 19  영등포구   75999.0  1.123775e+07  0.006763    1.340000   98.660000
# 1    강동구   96625.0  1.243774e+07  0.007769    4.231924   95.768076
# 3    강서구   98275.0  1.258730e+07  0.007807    4.343411   95.656589
# 6    구로구   71647.0  8.872029e+06  0.008076    5.114306   94.885694
# 11   동작구   71971.0  8.603271e+06  0.008366    5.947885   94.052115
# 20   용산구   59969.0  6.558848e+06  0.009143    8.183770   91.816230
# 18   양천구   82853.0  8.291396e+06  0.009993   10.625923   89.374077
# 14   서초구  163574.0  1.366494e+07  0.011970   16.311915   83.688085
# 23    중구   87758.0  5.964501e+06  0.014713   24.198332   75.801668
# 8    노원구  172591.0  1.081322e+07  0.015961   27.785633   72.214367
# 4    관악구  205162.0  1.095471e+07  0.018728   35.741152   64.258848
# 16   성북구  200008.0  9.912058e+06  0.020178   39.910157   60.089843
# 13  서대문구  182865.0  8.651923e+06  0.021136   42.663059   57.336941
# 12   마포구  253066.0  1.032453e+07  0.024511   52.367468   47.632532
# 10  동대문구  208830.0  8.506638e+06  0.024549   52.476510   47.523490
# 21   은평구  246740.0  9.694809e+06  0.025451   55.068862   44.931138
# 7    금천구  124102.0  4.815191e+06  0.025773   55.995450   44.004550
# 15   성동구  218728.0  8.283346e+06  0.026406   57.814603   42.185397
# 9    도봉구  161366.0  6.013007e+06  0.026836   59.052045   40.947955
# 24   중랑구  210696.0  7.766232e+06  0.027130   59.896167   40.103833
# 5    광진구  321873.0  8.536356e+06  0.037706   90.303893    9.696107
# 2    강북구  249473.0  6.073061e+06  0.041079  100.000000    0.000000

# %% [markdown]
# ### 2-5. 인구증가율점수

# %%
import pandas as pd
import numpy as np
import re

pop = pd.read_csv("/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/서울시 주민등록인구및세대현황.csv",
    encoding="cp949")

pop.head()
# Out:
#                      행정구역 2024년_총인구수  2024년_세대수  2024년_세대당 인구 2025년_총인구수  \
# 0     서울특별시  (1100000000)  9,331,828  4,482,063          2.08  9,299,548
# 1  서울특별시 종로구 (1111000000)    138,336     72,166          1.92    137,048
# 2   서울특별시 중구 (1114000000)    120,544     64,995          1.85    117,805
# 3  서울특별시 용산구 (1117000000)    203,854    103,241          1.97    201,894
# 4  서울특별시 성동구 (1120000000)    273,669    131,953          2.07    274,606
#
#    2025년_세대수  2025년_세대당 인구
# 0  4,501,031          2.07
# 1     72,324          1.89
# 2     63,817          1.85
# 3    102,959          1.96
# 4    133,173          2.06

# %%
pop = pop.copy()

seoul_gu = [
    "종로구", "중구", "용산구", "성동구", "광진구",
    "동대문구", "중랑구", "성북구", "강북구", "도봉구",
    "노원구", "은평구", "서대문구", "마포구", "양천구",
    "강서구", "구로구", "금천구", "영등포구", "동작구",
    "관악구", "서초구", "강남구", "송파구", "강동구"
]

pop["자치구"] = pop["행정구역"].astype(str).str.extract(
    "(" + "|".join(seoul_gu) + ")"
)

pop = pop.dropna(subset=["자치구"]).copy()

pop = pop[
    [
        "자치구",
        "2024년_총인구수",
        "2025년_총인구수"
    ]
].copy()

pop.head()
# Out:
#    자치구 2024년_총인구수 2025년_총인구수
# 1  종로구    138,336    137,048
# 2   중구    120,544    117,805
# 3  용산구    203,854    201,894
# 4  성동구    273,669    274,606
# 5  광진구    331,963    331,167

# %%
for col in ["2024년_총인구수", "2025년_총인구수"]:
    pop[col] = (
        pop[col]
        .astype(str)
        .str.replace(",", "", regex=False)
        .str.strip()
    )
    pop[col] = pd.to_numeric(pop[col], errors="coerce")

pop = pop.dropna(subset=["2024년_총인구수", "2025년_총인구수"]).copy()

pop["2024년_총인구수"] = pop["2024년_총인구수"].astype(int)
pop["2025년_총인구수"] = pop["2025년_총인구수"].astype(int)

pop["인구증감수"] = pop["2025년_총인구수"] - pop["2024년_총인구수"]

pop["인구증가율"] = pop["인구증감수"] / pop["2024년_총인구수"] * 100

# %%
# Min-Max 정규화
def minmax_100(series):
    min_val = series.min()
    max_val = series.max()

    if max_val == min_val:
        return series * 0

    return (series - min_val) / (max_val - min_val) * 100

pop["인구증가율점수"] = minmax_100(pop["인구증가율"])

# %%
pop_result = pop[
    [
        "자치구",
        "2024년_총인구수",
        "2025년_총인구수",
        "인구증감수",
        "인구증가율",
        "인구증가율점수"
    ]
].copy()

pop_result["인구증가율"] = pop_result["인구증가율"].round(4)
pop_result["인구증가율점수"] = pop_result["인구증가율점수"].round(2)

pop_result
# Out:
#      자치구  2024년_총인구수  2025년_총인구수  인구증감수   인구증가율  인구증가율점수
# 1    종로구      138336      137048  -1288 -0.9311    19.37
# 2     중구      120544      117805  -2739 -2.2722     0.00
# 3    용산구      203854      201894  -1960 -0.9615    18.93
# 4    성동구      273669      274606    937  0.3424    37.76
# 5    광진구      331963      331167   -796 -0.2398    29.35
# 6   동대문구      338735      346241   7506  2.2159    64.82
# 7    중랑구      379274      376916  -2358 -0.6217    23.84
# 8    성북구      421560      422559    999  0.2370    36.24
# 9    강북구      283597      278928  -4669 -1.6464     9.04
# 10   도봉구      303228      299899  -3329 -1.0979    16.96
# 11   노원구      491247      483541  -7706 -1.5687    10.16
# 12   은평구      460919      455137  -5782 -1.2545    14.70
# 13  서대문구      302853      300147  -2706 -0.8935    19.91
# 14   마포구      361417      357616  -3801 -1.0517    17.63
# 15   양천구      430976      425088  -5888 -1.3662    13.09
# 16   강서구      556171      549711  -6460 -1.1615    16.04
# 17   구로구      388169      383829  -4340 -1.1181    16.67
# 18   금천구      225159      223290  -1869 -0.8301    20.83
# 19  영등포구      373773      371362  -2411 -0.6450    23.50
# 20   동작구      375799      371924  -3875 -1.0311    17.92
# 21   관악구      477812      477605   -207 -0.0433    32.19
# 22   서초구      408376      414428   6052  1.4820    54.22
# 23   강남구      557345      556330  -1015 -0.1821    30.19
# 24   송파구      650110      643350  -6760 -1.0398    17.80
# 25   강동구      476942      499127  22185  4.6515   100.00

# %% [markdown]
# ### 2-6. Potential Score K-Means Clustering

# %%
# 점수 데이터 병합
potential = (
    topic_turnover[
        ["자치구", "KDC주제", "주제별_장서회전점수"]
    ]
    .merge(
        preference_long[
            ["자치구", "KDC주제", "주제선호도점수"]
        ],
        on=["자치구", "KDC주제"],
        how="left"
    )
    .merge(
        df_analysis[
            ["자치구", "장서부족도점수"]
        ],
        on="자치구",
        how="left"
    )
    .merge(
        gu_36month[
            ["자치구명", "생활인구점수"]
        ],
        left_on="자치구",
        right_on="자치구명",
        how="left"
    )
    .drop(columns="자치구명")
    .merge(
        pop_result[
            ["자치구", "인구증가율점수"]
        ],
        on="자치구",
        how="left"
    )
)

# Potential Score 계산
potential["Potential Score"] = (
    0.30 * potential["주제별_장서회전점수"] +
    0.20 * potential["주제선호도점수"] +
    0.20 * potential["장서부족도점수"] +
    0.20 * potential["생활인구점수"] +
    0.10 * potential["인구증가율점수"]
)

# 점수 높은 순으로 정렬
potential = (
    potential
    .sort_values("Potential Score", ascending=False)
    .reset_index(drop=True)
)

potential
# Out:
#      자치구 KDC주제  주제별_장서회전점수   주제선호도점수     장서부족도점수  생활인구점수  인구증가율점수  \
# 0    강남구  자연과학     89.0715   86.8300   99.771400  100.00    30.19
# 1    송파구    예술    100.0000  100.0000  100.000000   70.87    17.80
# 2    송파구  자연과학    100.0000  100.0000  100.000000   70.87    17.80
# 3    송파구    역사     99.9913  100.0000  100.000000   70.87    17.80
# 4    강동구    언어     95.2453  100.0000   95.768076   35.44   100.00
# ..   ...   ...         ...       ...         ...     ...      ...
# 245  용산구    예술      0.0000    3.8544   91.816230   10.09    18.93
# 246  용산구    종교      0.0000    2.4735   91.816230   10.09    18.93
# 247  용산구  자연과학      0.0000    0.9188   91.816230   10.09    18.93
# 248  용산구    언어      0.0000    0.4390   91.816230   10.09    18.93
# 249  용산구    총류      0.0000    0.0000   91.816230   10.09    18.93
#
#      Potential Score
# 0          87.060730
# 1          85.954000
# 2          85.954000
# 3          85.951390
# 4          84.815205
# ..               ...
# 245        23.045126
# 246        22.768946
# 247        22.458006
# 248        22.362046
# 249        22.274246
#
# [250 rows x 8 columns]

# %%
display(potential.head(10).round(2))
# Out:
#    자치구 KDC주제  주제별_장서회전점수  주제선호도점수  장서부족도점수  생활인구점수  인구증가율점수  Potential Score
# 0  강남구  자연과학       89.07    86.83    99.77  100.00    30.19            87.06
# 1  송파구    예술      100.00   100.00   100.00   70.87    17.80            85.95
# 2  송파구  자연과학      100.00   100.00   100.00   70.87    17.80            85.95
# 3  송파구    역사       99.99   100.00   100.00   70.87    17.80            85.95
# 4  강동구    언어       95.25   100.00    95.77   35.44   100.00            84.82
# 5  서초구    문학       96.76   100.00    83.69   57.67    54.22            82.72
# 6  강남구    역사       83.47    66.30    99.77  100.00    30.19            81.27
# 7  강남구    예술       91.09    47.54    99.77  100.00    30.19            79.81
# 8  강남구    문학       88.42    50.68    99.77  100.00    30.19            79.64
# 9  강남구  기술과학       99.22    26.54    99.77  100.00    30.19            78.05

# %%
display(potential.tail(10).round(2))
# Out:
#      자치구 KDC주제  주제별_장서회전점수  주제선호도점수  장서부족도점수  생활인구점수  인구증가율점수  Potential Score
# 240  강북구  기술과학       73.76    14.89     0.00    3.39     9.04            26.69
# 241  강북구    예술       66.82    19.27     0.00    3.39     9.04            25.48
# 242  강북구  사회과학       68.97    15.69     0.00    3.39     9.04            25.41
# 243  강북구    문학       73.00     7.71     0.00    3.39     9.04            25.02
# 244  금천구    총류       41.79     0.00    44.00    0.00    20.83            23.42
# 245  용산구    예술        0.00     3.85    91.82   10.09    18.93            23.05
# 246  용산구    종교        0.00     2.47    91.82   10.09    18.93            22.77
# 247  용산구  자연과학        0.00     0.92    91.82   10.09    18.93            22.46
# 248  용산구    언어        0.00     0.44    91.82   10.09    18.93            22.36
# 249  용산구    총류        0.00     0.00    91.82   10.09    18.93            22.27

# %%
# PriorityScore 기반 K-Means 클러스터링
from sklearn.cluster import KMeans
import numpy as np

X_score = df_gu_summary[['PriorityScore']].values
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42, n_init=10)
df_gu_summary['cluster_label'] = kmeans.fit_predict(X_score)

# 클러스터 번호별 평균 점수를 계산하여 높은 순서대로 상, 중, 하 등급 부여
centers = kmeans.cluster_centers_.flatten()
sorted_indices = np.argsort(centers)[::-1]

rank_map = {
    sorted_indices[0]: '상',
    sorted_indices[1]: '중',
    sorted_indices[2]: '하'
}

df_gu_summary['Priority_등급'] = df_gu_summary['cluster_label'].map(rank_map)

priority_ranking = df_gu_summary[[
    '자치구', 'PriorityScore', 'Priority_등급'
]].sort_values(by='PriorityScore', ascending=False).reset_index(drop=True)

print("클러스터 중심점")
for idx, center in enumerate(centers):
    print(f"클러스터 {idx}: {center:.2f}점")

print("자치구별 등급 분류")
display(priority_ranking)
# Out:
# 클러스터 중심점
# 클러스터 0: 32.01점
# 클러스터 1: 49.95점
# 클러스터 2: 14.35점
# 자치구별 등급 분류
#      자치구  PriorityScore Priority_등급
# 0    용산구      63.579169           상
# 1   동대문구      53.346350           상
# 2    구로구      52.946919           상
# 3     중구      52.891903           상
# 4    금천구      51.367492           상
# 5    종로구      46.796255           상
# 6    양천구      44.449010           상
# 7    성북구      42.958696           상
# 8   서대문구      41.206846           상
# 9    도봉구      37.247990           중
# 10   관악구      36.612472           중
# 11   강북구      36.264961           중
# 12   은평구      35.443937           중
# 13   동작구      34.662682           중
# 14   성동구      30.749124           중
# 15   강서구      29.854889           중
# 16   중랑구      27.767190           중
# 17  영등포구      27.043595           중
# 18   강동구      24.412166           중
# 19   노원구      21.725147           하
# 20   마포구      19.373149           하
# 21   강남구      16.668593           하
# 22   서초구      14.296738           하
# 23   송파구      11.968303           하
# 24   광진구       2.077645           하

# %% [markdown]
# ##3. Transfer Score: 이관 추천 점수
# 후보 자치구 Potential Score - 현재 자치구 Potential Score
# 정독도서관이 속한 종로구를 기준으로 산출하였다.

# %%
import pandas as pd

current_gu = "종로구"

current_potential = (
    potential[
        potential["자치구"] == current_gu
    ][
        ["KDC주제", "Potential Score"]
    ]
    .rename(
        columns={
            "Potential Score": "현재_Potential_Score"
        }
    )
)

transfer_score = (
    potential[
        potential["자치구"] != current_gu
    ][
        ["자치구", "KDC주제", "Potential Score"]
    ]
    .rename(
        columns={
            "자치구": "후보_자치구",
            "Potential Score": "후보_Potential_Score"
        }
    )
    .merge(
        current_potential,
        on="KDC주제",
        how="left"
    )
)

transfer_score["Transfer Score"] = (
    transfer_score["후보_Potential_Score"]
    - transfer_score["현재_Potential_Score"]
)

transfer_score = (
    transfer_score
    .sort_values(
        ["KDC주제", "Transfer Score"],
        ascending=[True, False]
    )
    .reset_index(drop=True)
)

display(transfer_score)
# Out:
#     후보_자치구 KDC주제  후보_Potential_Score  현재_Potential_Score  Transfer Score
# 0      강남구  기술과학           78.046450           56.156719       21.889731
# 1      송파구  기술과학           67.157140           56.156719       11.000421
# 2      강동구  기술과학           66.468285           56.156719       10.311566
# 3      서초구  기술과학           62.992927           56.156719        6.836208
# 4      노원구  기술과학           60.792323           56.156719        4.635604
# ..     ...   ...                 ...                 ...             ...
# 235     중구    총류           32.463964           50.910379      -18.446415
# 236    강북구    총류           30.658280           50.910379      -20.252099
# 237    중랑구    총류           30.253727           50.910379      -20.656652
# 238    금천구    총류           23.419980           50.910379      -27.490399
# 239    용산구    총류           22.274246           50.910379      -28.636133
#
# [240 rows x 5 columns]

# %%
#주제별 추천 자치구
best_transfer_by_topic = (
    transfer_score
    .sort_values(
        ["KDC주제", "Transfer Score"],
        ascending=[True, False]
    )
    .groupby(
        "KDC주제",
        as_index=False
    )
    .first()
)

display(best_transfer_by_topic.round(2))
# Out:
#   KDC주제 후보_자치구  후보_Potential_Score  현재_Potential_Score  Transfer Score
# 0  기술과학    강남구               78.05               56.16           21.89
# 1    문학    서초구               82.72               42.45           40.27
# 2  사회과학    강남구               69.51               51.46           18.05
# 3    언어    강동구               84.82               42.39           42.42
# 4    역사    송파구               85.95               49.33           36.62
# 5    예술    송파구               85.95               60.05           25.90
# 6  자연과학    강남구               87.06               43.04           44.02
# 7    종교    강남구               73.72               49.93           23.79
# 8    철학    강남구               69.36               61.47            7.89
# 9    총류    강남구               72.00               50.91           21.09

# %%
#Transfer Score가 양수
recommended_transfer = (
    transfer_score[
        transfer_score["Transfer Score"] > 0
    ]
    .sort_values(
        ["KDC주제", "Transfer Score"],
        ascending=[True, False]
    )
    .reset_index(drop=True)
)

display(recommended_transfer)
# Out:
#    후보_자치구 KDC주제  후보_Potential_Score  현재_Potential_Score  Transfer Score
# 0     강남구  기술과학           78.046450           56.156719       21.889731
# 1     송파구  기술과학           67.157140           56.156719       11.000421
# 2     강동구  기술과학           66.468285           56.156719       10.311566
# 3     서초구  기술과학           62.992927           56.156719        6.836208
# 4     노원구  기술과학           60.792323           56.156719        4.635604
# ..    ...   ...                 ...                 ...             ...
# 91   영등포구    총류           58.164730           50.910379        7.254351
# 92    강동구    총류           55.246125           50.910379        4.335746
# 93    광진구    총류           53.313851           50.910379        2.403472
# 94    관악구    총류           53.282070           50.910379        2.371691
# 95    마포구    총류           51.509186           50.910379        0.598807
#
# [96 rows x 5 columns]

# %%
#주제별 상위 3개 후보 자치구
top3_transfer_by_topic = (
    recommended_transfer
    .groupby(
        "KDC주제",
        group_keys=False
    )
    .head(3)
    .reset_index(drop=True)
)

display(top3_transfer_by_topic.round(2))
# Out:
#    후보_자치구 KDC주제  후보_Potential_Score  현재_Potential_Score  Transfer Score
# 0     강남구  기술과학               78.05               56.16           21.89
# 1     송파구  기술과학               67.16               56.16           11.00
# 2     강동구  기술과학               66.47               56.16           10.31
# 3     서초구    문학               82.72               42.45           40.27
# 4     강남구    문학               79.64               42.45           37.19
# 5     강동구    문학               70.02               42.45           27.57
# 6     강남구  사회과학               69.51               51.46           18.05
# 7     송파구  사회과학               65.12               51.46           13.65
# 8     강동구  사회과학               64.96               51.46           13.50
# 9     강동구    언어               84.82               42.39           42.42
# 10    송파구    언어               76.85               42.39           34.46
# 11    강남구    언어               75.36               42.39           32.97
# 12    송파구    역사               85.95               49.33           36.62
# 13    강남구    역사               81.27               49.33           31.94
# 14    강서구    역사               74.73               49.33           25.40
# 15    송파구    예술               85.95               60.05           25.90
# 16    강남구    예술               79.81               60.05           19.76
# 17    강동구    예술               65.26               60.05            5.21
# 18    강남구  자연과학               87.06               43.04           44.02
# 19    송파구  자연과학               85.95               43.04           42.91
# 20    강동구  자연과학               68.17               43.04           25.12
# 21    강남구    종교               73.72               49.93           23.79
# 22    강동구    종교               72.11               49.93           22.18
# 23    송파구    종교               64.27               49.93           14.35
# 24    강남구    철학               69.36               61.47            7.89
# 25    강서구    철학               66.14               61.47            4.67
# 26    강동구    철학               64.21               61.47            2.74
# 27    강남구    총류               72.00               50.91           21.09
# 28    송파구    총류               68.29               50.91           17.38
# 29    서초구    총류               64.77               50.91           13.86

# %%
output_path = (
    "/content/drive/MyDrive/ESAA YB 4조/"
    "*** 최종 ***/종로구_기준_이관추천점수.csv"
)

transfer_score.to_csv(
    output_path,
    index=False,
    encoding="utf-8-sig"
)

print("저장 완료:", output_path)
# Out:
# 저장 완료: /content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/종로구_기준_이관추천점수.csv

# %% [markdown]
# #모델링

# %% [markdown]
# ##1. 머신러닝 분류 모델링

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# 변수 세팅
label_map = {'상': 2, '중': 1, '하': 0}
df_gu_summary['Target_Score'] = df_gu_summary['Priority_등급'].map(label_map)

features = ['총소장권수', '연간대출건수', '인구증가율', '총세대수']
X = df_gu_summary[features]
y = df_gu_summary['Target_Score']

# 데이터 8:2 비율로 분할
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in sss.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

print(" 데이터셋 구성 결과")
print(f"전체 데이터 크기: {X.shape}")
print(f"학습 데이터 크기: {X_train.shape}")
print(f"테스트 데이터 크기: {X_test.shape}")

print("\n 학습 데이터 내 클래스 비율")
print(y_train.value_counts(normalize=True))

# 데이터셋 샘플 확인
display(X_train.head())
# Out:
#  데이터셋 구성 결과
# 전체 데이터 크기: (25, 4)
# 학습 데이터 크기: (20, 4)
# 테스트 데이터 크기: (5, 4)
#
#  학습 데이터 내 클래스 비율
# Target_Score
# 1    0.40
# 2    0.35
# 0    0.25
# Name: proportion, dtype: float64
#       총소장권수    연간대출건수     인구증가율      총세대수
# 10   350199   4059394  2.215891  174762.0
# 7    383146   4897633 -0.830080  121323.0
# 13   531726  11159229 -0.893503  146167.0
# 24   896513  23965564 -0.621714  189017.0
# 14  1068512  37281944  1.481968  172093.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 피처 분포 확인
plt.figure(figsize=(12, 4))
for i, col in enumerate(features):
    plt.subplot(1, 4, i+1)
    sns.boxplot(y=X_train[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# StandardScaler 적용
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"Scaled Train Shape: {X_train_scaled.shape}")
# Out:
# Scaled Train Shape: (20, 4)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 피처 분포 확인
plt.figure(figsize=(12, 4))
for i, col in enumerate(features):
    plt.subplot(1, 4, i+1)
    sns.boxplot(y=X_train[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# StandardScaler 적용
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"Scaled Train Shape: {X_train_scaled.shape}")
# Out:
# Scaled Train Shape: (20, 4)

# %% [markdown]
# ##2. RandomForest 모델링

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

rf_model = RandomForestClassifier(n_estimators=50, max_depth=3, random_state=42)
rf_scores = cross_val_score(rf_model, X_train_scaled, y_train, cv=3)

print("RandomForest 모델링")
print(f"각 Fold별 정확도: {rf_scores}")
print(f"평균 정확도: {rf_scores.mean():.4f}")
# Out:
# RandomForest 모델링
# 각 Fold별 정확도: [0.71428571 0.57142857 0.83333333]
# 평균 정확도: 0.7063

# %% [markdown]
# ##3. XGBoost 모델링

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

xgb_model = XGBClassifier(n_estimators=50, max_depth=2, learning_rate=0.1, random_state=42)
xgb_scores = cross_val_score(xgb_model, X_train_scaled, y_train, cv=3)

print("XGBoost 모델링")
print(f"각 Fold별 정확도: {xgb_scores}")
print(f"평균 정확도: {xgb_scores.mean():.4f}")
# Out:
# XGBoost 모델링
# 각 Fold별 정확도: [0.85714286 0.57142857 0.83333333]
# 평균 정확도: 0.7540

# %% [markdown]
# ##4. LightGBM 모델링

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score

lgbm_model = LGBMClassifier(n_estimators=50, max_depth=2, learning_rate=0.05,
                            min_child_samples=5, random_state=42, verbose=-1)
lgbm_scores = cross_val_score(lgbm_model, X_train_scaled, y_train, cv=3)

print("LightGBM 모델링")
print(f"각 Fold별 정확도: {lgbm_scores}")
print(f"평균 정확도: {lgbm_scores.mean():.4f}")
# Out:
# LightGBM 모델링
# 각 Fold별 정확도: [0.57142857 0.42857143 0.66666667]
# 평균 정확도: 0.5556
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ##5. 모델별 피처 중요도 시각화 및 규제

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

rf_model.fit(X_train_scaled, y_train)
xgb_model.fit(X_train_scaled, y_train)

ft_importances = pd.DataFrame({
    'Feature': features,
    'RandomForest': rf_model.feature_importances_,
    'XGBoost': xgb_model.feature_importances_
})

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.barplot(x='RandomForest', y='Feature', data=ft_importances.sort_values('RandomForest', ascending=False))
plt.title('RandomForest Feature Importance')

plt.subplot(1, 2, 2)
sns.barplot(x='XGBoost', y='Feature', data=ft_importances.sort_values('XGBoost', ascending=False))
plt.title('XGBoost Feature Importance')

plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import LeaveOneOut, cross_val_score
import numpy as np
import pandas as pd

loo = LeaveOneOut()

# 규제
lr_model = LogisticRegression(C=1.0, penalty='l2', solver='lbfgs', max_iter=1000, random_state=42)

rf_loo_scores = cross_val_score(rf_model, X_train_scaled, y_train, cv=loo)
xgb_loo_scores = cross_val_score(xgb_model, X_train_scaled, y_train, cv=loo)
lgbm_loo_scores = cross_val_score(lgbm_model, X_train_scaled, y_train, cv=loo)
lr_loo_scores = cross_val_score(lr_model, X_train_scaled, y_train, cv=loo)

print("LOOCV 평균 정확도")
print(f"Random Forest: {rf_loo_scores.mean():.4f}")
print(f"XGBoost: {xgb_loo_scores.mean():.4f}")
print(f"LightGBM: {lgbm_loo_scores.mean():.4f}")
print(f"Logistic Regression: {lr_loo_scores.mean():.4f}")

lr_model.fit(X_train_scaled, y_train)
for i, class_label in enumerate(['하', '중', '상']):
    print(f"\n[{class_label}] 등급 결정 가중치:")
    coef_df = pd.DataFrame({'Feature': features, 'Weight': lr_model.coef_[i]})
    display(coef_df.sort_values(by='Weight', ascending=False))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# LOOCV 평균 정확도
# Random Forest: 0.7500
# XGBoost: 0.8000
# LightGBM: 0.6500
# Logistic Regression: 0.7000
#
# [하] 등급 결정 가중치:
#   Feature    Weight
# 1  연간대출건수  1.184143
# 0   총소장권수  0.843630
# 3    총세대수  0.616902
# 2   인구증가율 -0.076331
# [중] 등급 결정 가중치:
#   Feature    Weight
# 3    총세대수  0.171563
# 0   총소장권수  0.081990
# 2   인구증가율 -0.018193
# 1  연간대출건수 -0.172064
# [상] 등급 결정 가중치:
#   Feature    Weight
# 2   인구증가율  0.094525
# 3    총세대수 -0.788465
# 0   총소장권수 -0.925620
# 1  연간대출건수 -1.012079

# %% [markdown]
# # 평가지표

# %% [markdown]
# ##1. 고정 테스트셋 기준 평가 지표
# X_test 약 5개에 대해 한 번 평가한 결과

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report
)
from sklearn.preprocessing import label_binarize
import pandas as pd
import numpy as np

models = {
    "Random Forest": rf_model,
    "XGBoost": xgb_model,
    "LightGBM": lgbm_model,
    "Logistic Regression": lr_model
}

evaluation_results = []

for model_name, model in models.items():

    model.fit(X_train_scaled, y_train)

    y_pred = model.predict(X_test_scaled)
    y_prob = model.predict_proba(X_test_scaled)

    accuracy = accuracy_score(y_test, y_pred)

    precision = precision_score(
        y_test,
        y_pred,
        average="macro",
        zero_division=0
    )

    recall = recall_score(
        y_test,
        y_pred,
        average="macro",
        zero_division=0
    )

    f1 = f1_score(
        y_test,
        y_pred,
        average="macro",
        zero_division=0
    )

    try:
        roc_auc = roc_auc_score(
            y_test,
            y_prob,
            multi_class="ovr",
            average="macro",
            labels=model.classes_
        )
    except ValueError:
        roc_auc = np.nan

    evaluation_results.append({
        "모델": model_name,
        "정확도": accuracy,
        "정밀도_Macro": precision,
        "재현율_Macro": recall,
        "F1_Score_Macro": f1,
        "ROC_AUC_Macro_OVR": roc_auc
    })

evaluation_df = pd.DataFrame(evaluation_results)

numeric_columns = [
    "정확도",
    "정밀도_Macro",
    "재현율_Macro",
    "F1_Score_Macro",
    "ROC_AUC_Macro_OVR"
]

evaluation_df[numeric_columns] = (
    evaluation_df[numeric_columns]
    .round(4)
)

display(
    evaluation_df.sort_values(
        "F1_Score_Macro",
        ascending=False
    )
)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#                     모델  정확도  정밀도_Macro  재현율_Macro  F1_Score_Macro  \
# 3  Logistic Regression  0.8     0.8889     0.8333          0.8222
# 1              XGBoost  0.6     0.6667     0.6667          0.6111
# 2             LightGBM  0.6     0.6667     0.6667          0.6111
# 0        Random Forest  0.4     0.4444     0.5000          0.3889
#
#    ROC_AUC_Macro_OVR
# 3             0.8889
# 1             0.8889
# 2             0.8333
# 0             0.7500

# %% [markdown]
# ##2. 교차검증으로 평가 지표 비교
# Stratified 3-Fold 교차검증

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate

cv = StratifiedKFold(
    n_splits=3,
    shuffle=True,
    random_state=42
)

scoring = {
    "accuracy": "accuracy",
    "precision_macro": "precision_macro",
    "recall_macro": "recall_macro",
    "f1_macro": "f1_macro",
    "roc_auc_ovr": "roc_auc_ovr"
}

cv_results_list = []

for model_name, model in models.items():

    cv_result = cross_validate(
        model,
        X_train_scaled,
        y_train,
        cv=cv,
        scoring=scoring,
        error_score=np.nan
    )

    cv_results_list.append({
        "모델": model_name,
        "정확도": np.nanmean(cv_result["test_accuracy"]),
        "정밀도_Macro": np.nanmean(
            cv_result["test_precision_macro"]
        ),
        "재현율_Macro": np.nanmean(
            cv_result["test_recall_macro"]
        ),
        "F1_Score_Macro": np.nanmean(
            cv_result["test_f1_macro"]
        ),
        "ROC_AUC_OVR": np.nanmean(
            cv_result["test_roc_auc_ovr"]
        )
    })

cv_evaluation_df = pd.DataFrame(cv_results_list)

cv_evaluation_df.iloc[:, 1:] = (
    cv_evaluation_df.iloc[:, 1:]
    .round(4)
)

display(
    cv_evaluation_df.sort_values(
        "F1_Score_Macro",
        ascending=False
    )
)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                     모델     정확도  정밀도_Macro  재현율_Macro  F1_Score_Macro  \
# 2             LightGBM  0.6905     0.7593     0.7407          0.7000
# 3  Logistic Regression  0.6508     0.6204     0.6481          0.5995
# 1              XGBoost  0.6508     0.5556     0.6667          0.5913
# 0        Random Forest  0.6429     0.5370     0.6667          0.5820
#
#    ROC_AUC_OVR
# 2       0.8728
# 3       0.8660
# 1       0.8585
# 0       0.8907
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %% [markdown]
# ##3. 클래스별 정밀도·재현율·F1-Score 확인

# %% [markdown]
# ###3-1. 고정 테스트 셋

# %%
class_name_map = {
    0: "하",
    1: "중",
    2: "상"
}

for model_name, model in models.items():

    y_pred = model.predict(X_test_scaled)

    print("=" * 60)
    print(model_name)
    print("=" * 60)

    report = classification_report(
        y_test,
        y_pred,
        labels=[0, 1, 2],
        target_names=["하", "중", "상"],
        zero_division=0,
        output_dict=True
    )

    report_df = pd.DataFrame(report).transpose().round(4)

    display(report_df)
# Out:
# ============================================================
# Random Forest
# ============================================================
#               precision  recall  f1-score  support
# 하                0.3333     1.0    0.5000      1.0
# 중                0.0000     0.0    0.0000      2.0
# 상                1.0000     0.5    0.6667      2.0
# accuracy         0.4000     0.4    0.4000      0.4
# macro avg        0.4444     0.5    0.3889      5.0
# weighted avg     0.4667     0.4    0.3667      5.0
# ============================================================
# XGBoost
# ============================================================
#               precision  recall  f1-score  support
# 하                0.5000  1.0000    0.6667      1.0
# 중                0.5000  0.5000    0.5000      2.0
# 상                1.0000  0.5000    0.6667      2.0
# accuracy         0.6000  0.6000    0.6000      0.6
# macro avg        0.6667  0.6667    0.6111      5.0
# weighted avg     0.7000  0.6000    0.6000      5.0
# ============================================================
# LightGBM
# ============================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#               precision  recall  f1-score  support
# 하                0.5000  1.0000    0.6667      1.0
# 중                0.5000  0.5000    0.5000      2.0
# 상                1.0000  0.5000    0.6667      2.0
# accuracy         0.6000  0.6000    0.6000      0.6
# macro avg        0.6667  0.6667    0.6111      5.0
# weighted avg     0.7000  0.6000    0.6000      5.0
# ============================================================
# Logistic Regression
# ============================================================
#               precision  recall  f1-score  support
# 하                1.0000  1.0000    1.0000      1.0
# 중                0.6667  1.0000    0.8000      2.0
# 상                1.0000  0.5000    0.6667      2.0
# accuracy         0.8000  0.8000    0.8000      0.8
# macro avg        0.8889  0.8333    0.8222      5.0
# weighted avg     0.8667  0.8000    0.7867      5.0

# %% [markdown]
# ###3-2. 교차검증

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.metrics import classification_report
import pandas as pd

cv = StratifiedKFold(
    n_splits=3,
    shuffle=True,
    random_state=42
)

for model_name, model in models.items():

    y_cv_pred = cross_val_predict(
        model,
        X_train_scaled,
        y_train,
        cv=cv
    )

    print("=" * 60)
    print(model_name)
    print("=" * 60)

    report = classification_report(
        y_train,
        y_cv_pred,
        labels=[0, 1, 2],
        target_names=["하", "중", "상"],
        zero_division=0,
        output_dict=True
    )

    report_df = pd.DataFrame(report).transpose().round(4)
    display(report_df)
# Out:
# ============================================================
# Random Forest
# ============================================================
#               precision  recall  f1-score  support
# 하                0.7500  0.6000    0.6667     5.00
# 중                0.5556  0.6250    0.5882     8.00
# 상                0.7143  0.7143    0.7143     7.00
# accuracy         0.6500  0.6500    0.6500     0.65
# macro avg        0.6733  0.6464    0.6564    20.00
# weighted avg     0.6597  0.6500    0.6520    20.00
# ============================================================
# XGBoost
# ============================================================
#               precision  recall  f1-score  support
# 하                1.0000  0.6000    0.7500     5.00
# 중                0.5556  0.6250    0.5882     8.00
# 상                0.6250  0.7143    0.6667     7.00
# accuracy         0.6500  0.6500    0.6500     0.65
# macro avg        0.7269  0.6464    0.6683    20.00
# weighted avg     0.6910  0.6500    0.6561    20.00
# ============================================================
# LightGBM
# ============================================================
#               precision  recall  f1-score  support
# 하                0.6667  0.8000    0.7273      5.0
# 중                0.6667  0.5000    0.5714      8.0
# 상                0.7500  0.8571    0.8000      7.0
# accuracy         0.7000  0.7000    0.7000      0.7
# macro avg        0.6944  0.7190    0.6996     20.0
# weighted avg     0.6958  0.7000    0.6904     20.0
# ============================================================
# Logistic Regression
# ============================================================
#               precision  recall  f1-score  support
# 하                0.6667  0.4000    0.5000     5.00
# 중                0.5556  0.6250    0.5882     8.00
# 상                0.7500  0.8571    0.8000     7.00
# accuracy         0.6500  0.6500    0.6500     0.65
# macro avg        0.6574  0.6274    0.6294    20.00
# weighted avg     0.6514  0.6500    0.6403    20.00

# %% [markdown]
# ##4. 혼동행렬

# %% [markdown]
# ###4-1. 고정 테스트 셋

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

for model_name, model in models.items():

    y_pred = model.predict(X_test_scaled)

    cm = confusion_matrix(
        y_test,
        y_pred,
        labels=[0, 1, 2]
    )

    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=["하", "중", "상"]
    )

    disp.plot()
    plt.title(f"{model_name} Confusion Matrix")
    plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ###4-2. 교차검증

# %%
X_train_scaled = pd.DataFrame(
    scaler.fit_transform(X_train),
    columns=features,
    index=X_train.index
)

X_test_scaled = pd.DataFrame(
    scaler.transform(X_test),
    columns=features,
    index=X_test.index
)

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cv = StratifiedKFold(
    n_splits=3,
    shuffle=True,
    random_state=42
)

for model_name, model in models.items():

    y_cv_pred = cross_val_predict(
        model,
        X_train_scaled,
        y_train,
        cv=cv
    )

    cm = confusion_matrix(
        y_train,
        y_cv_pred,
        labels=[0, 1, 2]
    )

    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=["하", "중", "상"]
    )

    disp.plot()
    plt.title(f"{model_name} Cross-Validation Confusion Matrix")
    plt.show()

# %% [markdown]
# ##5. 클래스별 ROC 곡선

# %% [markdown]
# ###5-1. 고정 테스트 셋

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

class_labels = [0, 1, 2]
class_names = ["하", "중", "상"]

y_test_bin = label_binarize(
    y_test,
    classes=class_labels
)

for model_name, model in models.items():

    model.fit(X_train_scaled, y_train)

    y_prob = model.predict_proba(X_test_scaled)

    plt.figure(figsize=(7, 5))

    valid_curve_count = 0

    for i, class_name in enumerate(class_names):

        if len(np.unique(y_test_bin[:, i])) < 2:
            print(
                f"{model_name} - {class_name}: "
                "테스트셋에 양성 또는 음성 표본이 없어 ROC 계산 불가"
            )
            continue

        fpr, tpr, _ = roc_curve(
            y_test_bin[:, i],
            y_prob[:, i]
        )

        class_auc = auc(fpr, tpr)

        plt.plot(
            fpr,
            tpr,
            label=f"{class_name} vs Rest (AUC={class_auc:.3f})"
        )

        valid_curve_count += 1

    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Random"
    )

    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"{model_name} ROC Curve - Fixed Test Set")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

    if valid_curve_count == 0:
        print(f"{model_name}: 표시할 수 있는 ROC 곡선이 없습니다.")

# %% [markdown]
# ###5-2. 교차검증

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import (
    StratifiedKFold,
    cross_val_predict
)
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.base import clone

cv = StratifiedKFold(
    n_splits=3,
    shuffle=True,
    random_state=42
)

class_labels = [0, 1, 2]
class_names = ["하", "중", "상"]

y_train_bin = label_binarize(
    y_train,
    classes=class_labels
)

for model_name, model in models.items():

    y_cv_prob = cross_val_predict(
        clone(model),
        X_train_scaled,
        y_train,
        cv=cv,
        method="predict_proba"
    )

    plt.figure(figsize=(7, 5))

    for i, class_name in enumerate(class_names):

        fpr, tpr, _ = roc_curve(
            y_train_bin[:, i],
            y_cv_prob[:, i]
        )

        class_auc = auc(fpr, tpr)

        plt.plot(
            fpr,
            tpr,
            label=f"{class_name} vs Rest (AUC={class_auc:.3f})"
        )

    plt.plot(
        [0, 1],
        [0, 1],
        linestyle="--",
        label="Random"
    )

    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"{model_name} ROC Curve - Cross Validation")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

# %% [markdown]
# # Recommendation Score
# - 서울시 자치구의 수요 적합성 평가

# %%
import pandas as pd

recommend = potential.copy()

recommend["Recommendation Score"] = (
      0.35 * recommend["주제선호도점수"]
    + 0.25 * recommend["주제별_장서회전점수"]
    + 0.20 * recommend["생활인구점수"]
    + 0.10 * recommend["인구증가율점수"]
    + 0.10 * recommend["장서부족도점수"]
)

# 높은 점수 순 정렬
recommend = (
    recommend
    .sort_values(
        ["KDC주제", "Recommendation Score"],
        ascending=[True, False]
    )
    .reset_index(drop=True)
)

display(recommend)
# Out:
#       자치구 KDC주제  주제별_장서회전점수   주제선호도점수    장서부족도점수  생활인구점수  인구증가율점수  \
# 0     강남구  기술과학     99.2191   26.5372  99.771400  100.00    30.19
# 1    동대문구  기술과학     49.0689  100.0000  47.523490   15.63    64.82
# 2     노원구  기술과학     87.9749   64.7249  72.214367   29.98    10.16
# 3     강동구  기술과학     90.6153   15.2104  95.768076   35.44   100.00
# 4     종로구  기술과학     56.8166   70.5502  99.153495   16.17    19.37
# ..    ...   ...         ...       ...        ...     ...      ...
# 245   양천구    총류     40.4354   20.5184  89.374077   16.01    13.09
# 246    중구    총류     25.3831   31.5335  75.801668   16.91     0.00
# 247   중랑구    총류     47.5534   16.4147  40.103833   11.50    23.84
# 248   금천구    총류     41.7869    0.0000  44.004550    0.00    20.83
# 249   용산구    총류      0.0000    0.0000  91.816230   10.09    18.93
#
#      Potential Score  Recommendation Score
# 0          78.046450             67.088935
# 1          53.833368             61.627574
# 2          60.792323             58.880877
# 3          66.468285             54.642273
# 4          56.156719             53.983069
# ..               ...                   ...
# 245        38.620115             30.738698
# 246        32.463964             28.344667
# 247        30.253727             26.327878
# 248        23.419980             16.930180
# 249        22.274246             13.092623
#
# [250 rows x 9 columns]

# %%
# KDC별 추천 자치구 Top3
top3 = (
    recommend
    .groupby("KDC주제")
    .head(3)
    .reset_index(drop=True)
)

display(top3)
# Out:
#      자치구 KDC주제  주제별_장서회전점수   주제선호도점수     장서부족도점수  생활인구점수  인구증가율점수  \
# 0    강남구  기술과학     99.2191   26.5372   99.771400  100.00    30.19
# 1   동대문구  기술과학     49.0689  100.0000   47.523490   15.63    64.82
# 2    노원구  기술과학     87.9749   64.7249   72.214367   29.98    10.16
# 3    서초구    문학     96.7619  100.0000   83.688085   57.67    54.22
# 4    강남구    문학     88.4197   50.6829   99.771400  100.00    30.19
# 5   영등포구    문학     83.1284   70.8780   98.660000   40.78    23.50
# 6   동대문구  사회과학     41.0136  100.0000   47.523490   15.63    64.82
# 7    강서구  사회과학     85.8371   49.5641   95.656589   40.96    16.04
# 8    강남구  사회과학     86.9730    2.2416   99.771400  100.00    30.19
# 9    강동구    언어     95.2453  100.0000   95.768076   35.44   100.00
# 10   송파구    언어     83.3439   79.4557  100.000000   70.87    17.80
# 11   강남구    언어     83.4938   36.6989   99.771400  100.00    30.19
# 12   송파구    역사     99.9913  100.0000  100.000000   70.87    17.80
# 13   강남구    역사     83.4684   66.3043   99.771400  100.00    30.19
# 14   강서구    역사     86.9752   98.5507   95.656589   40.96    16.04
# 15   송파구    예술    100.0000  100.0000  100.000000   70.87    17.80
# 16   강남구    예술     91.0858   47.5375   99.771400  100.00    30.19
# 17   종로구    예술     62.7218   81.1563   99.153495   16.17    19.37
# 18   송파구  자연과학    100.0000  100.0000  100.000000   70.87    17.80
# 19   강남구  자연과학     89.0715   86.8300   99.771400  100.00    30.19
# 20   강동구  자연과학     81.7177   37.0597   95.768076   35.44   100.00
# 21   성동구    종교     90.7574  100.0000   42.185397   17.36    37.76
# 22   강남구    종교     90.2302   18.3746   99.771400  100.00    30.19
# 23   강동구    종교    100.0000   29.3286   95.768076   35.44   100.00
# 24   종로구    철학     59.9469   92.4324   99.153495   16.17    19.37
# 25   관악구    철학     69.7554   85.9459   64.258848   26.19    32.19
# 26   강서구    철학     87.1158   55.4054   95.656589   40.96    16.04
# 27   강남구    총류     71.1329   38.4449   99.771400  100.00    30.19
# 28   광진구    총류     97.4377   79.4816    9.696107   16.56    29.35
# 29  동대문구    총류     37.9042  100.0000   47.523490   15.63    64.82
#
#     Potential Score  Recommendation Score
# 0         78.046450             67.088935
# 1         53.833368             61.627574
# 2         60.792323             58.880877
# 3         82.722187             84.515284
# 4         79.635770             72.840080
# 5         69.352120             65.961400
# 6         51.416778             59.613749
# 7         64.591268             58.168369
# 8         69.513500             55.523950
# 9         84.815205             85.476133
# 10        76.848310             74.599470
# 11        75.361200             66.714205
# 12        85.951390             85.951825
# 13        81.274660             77.069745
# 14        74.730018             75.598204
# 15        85.954000             85.954000
# 16        79.806520             72.405715
# 17        60.049499             59.171504
# 18        85.954000             85.954000
# 19        87.060730             85.654515
# 20        68.168865             60.065128
# 21        62.912299             69.155890
# 22        73.717260             61.984800
# 23        72.107335             61.929818
# 24        61.472249             62.424414
# 25        59.424570             62.402800
# 26        66.143138             60.532499
# 27        72.002130             64.235080
# 28        53.313851             59.394596
# 29        50.483958             58.836399

# %% [markdown]
# ### 실제 추천 함수

# %%
def recommend_library(kdc):

    result = (
        recommend[recommend["KDC주제"] == kdc]
        .sort_values(
            "Recommendation Score",
            ascending=False
        )
        .head(3)
    )

    return result[
        [
            "자치구",
            "Recommendation Score"
        ]
    ]

# %%
recommend_library("문학")
# Out:
#      자치구  Recommendation Score
# 25   서초구             84.515284
# 26   강남구             72.840080
# 27  영등포구             65.961400

# %% [markdown]
# # 시스템 시뮬레이션

# %%
cols_to_drop = [
    "인구증가율_x", "총세대수_x", "인구증가율_y", "총세대수_y",
    "인구증가율", "총세대수", "미래대출예측량", "미래대출지수정규화",
    "장기미대출비율", "장서회전율", "장서회전율정규화", "PriorityScore"
]
df_priority = df_priority.drop(columns=[c for c in cols_to_drop if c in df_priority.columns])

# %%
df_priority["장기미대출비율"] = (
    df_priority["장기미대출권수"] / df_priority["총소장권수"]
) * 100

df_priority["장서회전율"] = (
    df_priority["연간대출건수"] / df_priority["총소장권수"]
)
min_t = df_priority["장서회전율"].min()
max_t = df_priority["장서회전율"].max()
df_priority["장서회전율정규화"] = (df_priority["장서회전율"] - min_t) / (max_t - min_t) * 100

df_priority = df_priority.merge(pop_calc[["자치구", "인구증가율"]], on="자치구", how="left")
df_priority = df_priority.merge(df_households_per_gu, on="자치구", how="left")

avg_household = df_households_per_gu["총세대수"].mean()
df_priority["미래대출예측량"] = (
    df_priority["연간대출건수"]
    * (1 + df_priority["인구증가율"] / 100)
    * (df_priority["총세대수"] / avg_household)
)

min_f = df_priority["미래대출예측량"].min()
max_f = df_priority["미래대출예측량"].max()
df_priority["미래대출지수정규화"] = (
    (df_priority["미래대출예측량"] - min_f) / (max_f - min_f)
) * 100

df_priority["PriorityScore"] = (
    0.45 * df_priority["장기미대출비율"]
    + 0.30 * (100 - df_priority["장서회전율정규화"])
    + 0.25 * (100 - df_priority["미래대출지수정규화"])
)

# %%
source_gu = "종로구"

target_kdc = (
    df_priority[df_priority["자치구"] == source_gu]
    .sort_values("PriorityScore", ascending=False)
    .iloc[0]["KDC주제"]
)

file_path = "/content/drive/MyDrive/ESAA YB 4조/*** 최종 ***/장서대출_전처리/장서대출_종로구_전처리.csv"
df_jongno = pd.read_csv(file_path, low_memory=False)

kdc_map = {0:"총류",1:"철학",2:"종교",3:"사회과학",4:"자연과학",5:"기술과학",6:"예술",7:"언어",8:"문학",9:"역사"}
subj = df_jongno["주제분류번호"].astype(str)
df_jongno = df_jongno[subj.str[0].str.isdigit()].copy()
df_jongno["KDC주제"] = df_jongno["주제분류번호"].astype(str).str[0].astype(int).map(kdc_map)

candidate_books = df_jongno[
    (df_jongno["KDC주제"] == target_kdc) & (df_jongno["대출건수"] == 0)
].reset_index(drop=True)

candidate_books_clean = candidate_books[
    candidate_books["도서명"].astype(str).str.contains(r"[가-힣]", regex=True)
]
sample_book = candidate_books_clean.sort_values("도서명").iloc[0]

# %%
recommendation_result = recommend_library(target_kdc)
recommendation_result = recommendation_result[recommendation_result["자치구"] != source_gu]

print(f"이관 후보: {source_gu} - {target_kdc}")
print(f"선정 도서: {sample_book['도서명']} / 저자: {sample_book['저자']}")
print(recommendation_result.to_string(index=False))
# Out:
# 이관 후보: 종로구 - 총류
# 선정 도서:  6.25 전쟁기간 4대신문.경향신문 / 저자: LG상남언론재단 [편]
#  자치구  Recommendation Score
#  강남구             64.235080
#  광진구             59.394596
# 동대문구             58.836399
